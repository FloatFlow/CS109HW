# %% [markdown]
# # Homework 4: Can you predict the Midterm Elections?
#
# Due: Monday, November 3, 2014 11:59 PM
#
# <a href=https://raw.githubusercontent.com/cs109/2014/master/homework/HW4.ipynb download=HW4.ipynb> Download this assignment</a>
#
# #### Submission Instructions
# To submit your homework, create a folder named lastname_firstinitial_hw# and place your IPython notebooks, data files, and any other files in this folder. Your IPython Notebooks should be completely executed with the results visible in the notebook. We should not have to run any code. Compress the folder (please use .zip compression) and submit to the CS109 dropbox in the appropriate folder. If we cannot access your work because these directions are not followed correctly, we will not grade your work. For the competition (problem 4), we will post a link on Piazza to a Google Form for you to submit your predictions.
#
#
# ---

# %% [markdown]
# ## Introduction
#
# **Add Introduction**
#
# You will use the [HuffPost Pollster API](http://elections.huffingtonpost.com/pollster/api) to extract the polls for the current 2014 Senate Midterm Elections and provide a final prediction of the result of each state.
#
# #### Data
#
# We will use the polls from the [2014 Senate Midterm Elections](http://elections.huffingtonpost.com/pollster) from the [HuffPost Pollster API](http://elections.huffingtonpost.com/pollster/api).
#
# ---

# %% [markdown]
# ## Problem 1: Data Wrangling
#
# We will read in the polls from the [2014 Senate Midterm Elections](http://elections.huffingtonpost.com/pollster) from the [HuffPost Pollster API](http://elections.huffingtonpost.com/pollster/api) and create a dictionary of DataFrames as well a master table information for each race.

# %% [markdown]
# #### Problem 1(a)
#
# Read in [this JSON object](http://elections.huffingtonpost.com/pollster/api/charts/?topic=2014-senate) containing the polls for the 2014 Senate Elections using the HuffPost API. Call this JSON object `info`.  This JSON object is imported as a list in Python where each element contains the information for one race.  Use the function `type` to confirm the that `info` is a list.

# %%
# special IPython command to prepare the notebook for matplotlib
# %matplotlib inline 
import re
import requests 
import io
import zipfile
import numpy as np
import scipy
import pandas as pd # pandas
import matplotlib.pyplot as plt # module for plotting 

# If this module is not already installed, you may need to install it. 
# You can do this by typing 'pip install seaborn' in the command line
import seaborn as sns 

import sklearn
import sklearn.datasets
import sklearn.cross_validation
import sklearn.decomposition
import sklearn.grid_search
import sklearn.neighbors
import sklearn.metrics

# %%
from sklearn.cross_validation import train_test_split
from sklearn.grid_search import GridSearchCV
def cv_optimize(clf, parameters, Xtrain, ytrain, n_folds=5):
    gs = GridSearchCV(clf, param_grid=parameters, cv=n_folds)
    gs.fit(Xtrain, ytrain)
    print "BEST PARAMS", gs.best_params_
    best = gs.best_estimator_
    return best
def do_classify(clf, parameters, indf, featurenames, targetname, target1val, standardize=False, train_size=0.8):
    subdf=indf[featurenames]
    if standardize:
        subdfstd=(subdf - subdf.mean())/subdf.std()
    else:
        subdfstd=subdf
    X=subdfstd.values
    y=(indf[targetname].values==target1val)*1
    Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, train_size=train_size)
    clf = cv_optimize(clf, parameters, Xtrain, ytrain)
    clf=clf.fit(Xtrain, ytrain)
    training_accuracy = clf.score(Xtrain, ytrain)
    test_accuracy = clf.score(Xtest, ytest)
    print "Accuracy on training data: %0.2f" % (training_accuracy)
    print "Accuracy on test data:     %0.2f" % (test_accuracy)
    return clf, Xtrain, ytrain, Xtest, ytest

# %%
url = 'http://elections.huffingtonpost.com/pollster/api/charts/?topic=2014-senate'
info = requests.get(url).json()

# %% [markdown]
# #### Problem 1(b)
#
# For each element of the list in `info` extract the state. We should have one poll per state, but we do not. Why?
#
# **Hint**: Use the internet to find out information on the races in each state that has more than one entry. Eliminate entries of the list that represent races that are not happening.

# %%
states = [str(ele['state']) for ele in info]
titles = [str(ele['title']) for ele in info]
print(states)
# Out:
# ['DE', 'MA', 'RI', 'MT', 'OK', 'HI', 'KS', 'WY', 'TN', 'ID', 'NJ', 'NM', 'OK', 'SC', 'SC', 'TX', 'MN', 'ME', 'SD', 'NE', 'GA', 'OR', 'MS', 'IA', 'AK', 'IL', 'CO', 'VA', 'NC', 'NH', 'WV', 'NH', 'LA', 'MI', 'AR', 'KY']

# %%
from collections import Counter
countstates = Counter(states)
duplicate = [k for (k,v) in countstates.items() if v > 1]
duplicate
# Out:
# ['OK', 'SC', 'NH']

# %%
for dups in duplicate:
    ind = [i for i,x in enumerate(states) if x == dups ]
    for ele in ind:
        print(titles[ele], ele)
# Out:
# 2014 Oklahoma Senate: Lankford vs. Johnson 4
# 2014 Oklahoma Senate: Inhofe vs. Silverstein 12
# 2014 South Carolina Senate: Scott vs. Dickerson 13
# 2014 South Carolina Senate: Graham vs. Hutto 14
# 2014 New Hampshire Senate: Bass vs. Shaheen 29
# 2014 New Hampshire Senate: Brown vs. Shaheen 31

# %%
idx = [29]
editinfo = [i for (j,i) in enumerate(info) if j not in idx]
print(len(info))
print(len(editinfo))
# Out:
# 36
# 35

# %%
editinfo
# Out:
# [{'election_date': '2014-11-04',
#   'estimates': [{'choice': 'Coons',
#     'first_name': 'Chris',
#     'incumbent': True,
#     'last_name': 'Coons',
#     'lead_confidence': 99.9,
#     'party': 'Dem',
#     'value': 56.0},
#    {'choice': 'Wade',
#     'first_name': 'Kevin',
#     'incumbent': False,
#     'last_name': 'Wade',
#     'lead_confidence': 0.0,
#     'party': 'Rep',
#     'value': 34.0}],
#   'id': 571,
#   'last_updated': '2016-06-06T14:37:54.000Z',
#   'poll_count': 5,
#   'short_title': '2014 Delaware Senate: Wade vs. Coons',
#   'slug': '2014-delaware-senate-wade-vs-coons',
#   'state': 'DE',
#   'title': '2014 Delaware Senate: Wade vs. Coons',
#   'topic': '2014-senate',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-delaware-senate-wade-vs-coons'},
#  {'election_date': '2014-11-04',
#   'estimates': [{'choice': 'Markey',
#     'first_name': 'Ed',
#     'incumbent': True,
#     'last_name': 'Markey',
#     'lead_confidence': 99.9,
#     'party': 'Dem',
#     'value': 54.1},
#    {'choice': 'Herr',
#     'first_name': 'Brian',
#     'incumbent': False,
#     'last_name': 'Herr',
#     'lead_confidence': 0.0,
#     'party': 'Rep',
#     'value': 33.4},
#    {'choice': 'Other',
#     'first_name': None,
#     'incumbent': False,
#     'last_name': None,
#     'lead_confidence': None,
#     'party': 'N/A',
#     'value': 0.18}],
#   'id': 570,
#   'last_updated': '2016-06-06T14:37:55.000Z',
#   'poll_count': 13,
#   'short_title': '2014 Massachusetts Senate: Herr vs. Markey',
#   'slug': '2014-massachusetts-senate-herr-vs-markey',
#   'state': 'MA',
#   'title': '2014 Massachusetts Senate: Herr vs. Markey',
#   'topic': '2014-senate',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-massachusetts-senate-herr-vs-markey'},
#  {'election_date': '2014-11-04',
#   'estimates': [],
#   'id': 569,
#   'last_updated': '2016-06-06T14:37:55.000Z',
#   'poll_count': 4,
#   'short_title': '2014 Rhode Island Senate: Zaccaria vs. Reed',
#   'slug': '2014-rhode-island-senate-zaccaria-vs-reed',
#   'state': 'RI',
#   'title': '2014 Rhode Island Senate: Zaccaria vs. Reed',
#   'topic': '2014-senate',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-rhode-island-senate-zaccaria-vs-reed'},
#  {'election_date': '2014-11-04',
#   'estimates': [{'choice': 'Daines',
#     'first_name': 'Steve',
#     'incumbent': False,
#     'last_name': 'Daines',
#     'lead_confidence': 99.9,
#     'party': 'Rep',
#     'value': 53.8},
#    {'choice': 'Curtis',
#     'first_name': 'Amanda',
#     'incumbent': False,
#     'last_name': 'Curtis',
#     'lead_confidence': 0.0,
#     'party': 'Dem',
#     'value': 36.1}],
#   'id': 568,
#   'last_updated': '2016-06-06T14:37:56.000Z',
#   'poll_count': 7,
#   'short_title': '2014 Montana Senate: Daines vs. Curtis',
#   'slug': '2014-montana-senate-daines-vs-curtis',
#   'state': 'MT',
#   'title': '2014 Montana Senate: Daines vs. Curtis',
#   'topic': '2014-senate',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-montana-senate-daines-vs-curtis'},
#  {'election_date': '2014-11-04',
#   'estimates': [{'choice': 'Lankford',
#     'first_name': 'James',
#     'incumbent': False,
#     'last_name': 'Lankford',
#     'lead_confidence': 100.0,
#     'party': 'Rep',
#     'value': 62.4},
#    {'choice': 'Johnson',
#     'first_name': 'Connie',
#     'incumbent': False,
#     'last_name': 'Johnson',
#     'lead_confidence': 0.0,
#     'party': 'Dem',
#     'value': 28.6},
#    {'choice': 'Other',
#     'first_name': None,
#     'incumbent': False,
#     'last_name': None,
#     'lead_confidence': None,
#     'party': 'N/A',
#     'value': 2.3}],
#   'id': 567,
#   'last_updated': '2016-06-06T14:37:56.000Z',
#   'poll_count': 8,
#   'short_title': '2014 Oklahoma Senate: Lankford vs. Johnson',
#   'slug': '2014-oklahoma-senate-lankford-vs-johnson',
#   'state': 'OK',
#   'title': '2014 Oklahoma Senate: Lankford vs. Johnson',
#   'topic': '2014-senate',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-oklahoma-senate-lankford-vs-johnson'},
#  {'election_date': '2014-11-04',
#   'estimates': [{'choice': 'Schatz',
#     'first_name': 'Brian',
#     'incumbent': True,
#     'last_name': 'Schatz',
#     'lead_confidence': 100.0,
#     'party': 'Dem',
#     'value': 67.9},
#    {'choice': 'Cavasso',
#     'first_name': 'Campbell',
#     'incumbent': False,
#     'last_name': 'Cavasso',
#     'lead_confidence': 0.0,
#     'party': 'Rep',
#     'value': 20.2},
#    {'choice': 'Other',
#     'first_name': None,
#     'incumbent': False,
#     'last_name': None,
#     'lead_confidence': None,
#     'party': 'N/A',
#     'value': 1.0}],
#   'id': 566,
#   'last_updated': '2016-06-06T14:37:57.000Z',
#   'poll_count': 8,
#   'short_title': '2014 Hawaii Senate',
#   'slug': '2014-hawaii-senate-cavasso-vs-schatz',
#   'state': 'HI',
#   'title': '2014 Hawaii Senate: Cavasso vs. Schatz',
#   'topic': '2014-senate',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-hawaii-senate-cavasso-vs-schatz'},
#  {'election_date': '2014-11-04',
#   'estimates': [{'choice': 'Orman',
#     'first_name': 'Greg',
#     'incumbent': False,
#     'last_name': 'Orman',
#     'lead_confidence': 25.9,
#     'party': 'ind',
#     'value': 45.0},
#    {'choice': 'Roberts',
#     'first_name': 'Pat',
#     'incumbent': True,
#     'last_name': 'Roberts',
#     'lead_confidence': 74.1,
#     'party': 'Rep',
#     'value': 46.7},
#    {'choice': 'Other',
#     'first_name': None,
#     'incumbent': False,
#     'last_name': None,
#     'lead_confidence': None,
#     'party': 'N/A',
#     'value': 3.66}],
#   'id': 560,
#   'last_updated': '2016-06-06T14:38:02.000Z',
#   'poll_count': 27,
#   'short_title': '2014 Kansas Senate',
#   'slug': '2014-kansas-senate-roberts-vs-orman-vs-taylor',
#   'state': 'KS',
#   'title': '2014 Kansas Senate',
#   'topic': '2014-senate',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-kansas-senate-roberts-vs-orman-vs-taylor'},
#  {'election_date': '2014-11-04',
#   'estimates': [{'choice': 'Enzi',
#     'first_name': 'Mike',
#     'incumbent': True,
#     'last_name': 'Enzi',
#     'lead_confidence': 100.0,
#     'party': 'Rep',
#     'value': 68.9},
#    {'choice': 'Hardy',
#     'first_name': 'Charlie',
#     'incumbent': False,
#     'last_name': 'Hardy',
#     'lead_confidence': 0.0,
#     'party': 'Dem',
#     'value': 25.5}],
#   'id': 555,
#   'last_updated': '2016-06-06T14:38:05.000Z',
#   'poll_count': 5,
#   'short_title': '2014 Wyoming Senate',
#   'slug': '2014-wyoming-senate',
#   'state': 'WY',
#   'title': '2014 Wyoming Senate: Enzi vs. Hardy',
#   'topic': '2014-senate',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-wyoming-senate'},
#  {'election_date': '2014-11-04',
#   'estimates': [{'choice': 'Alexander',
#     'first_name': 'Lamar',
#     'incumbent': True,
#     'last_name': 'Alexander',
#     'lead_confidence': 100.0,
#     'party': 'Rep',
#     'value': 55.3},
#    {'choice': 'Ball',
#     'first_name': 'Gordon',
#     'incumbent': False,
#     'last_name': 'Ball',
#     'lead_confidence': 0.0,
#     'party': 'Dem',
#     'value': 32.5},
#    {'choice': 'Other',
#     'first_name': None,
#     'incumbent': False,
#     'last_name': None,
#     'lead_confidence': None,
#     'party': 'N/A',
#     'value': 1.16}],
#   'id': 550,
#   'last_updated': '2016-06-06T14:38:08.000Z',
#   'poll_count': 6,
#   'short_title': '2014 Tennessee Senate',
#   'slug': '2014-tennessee-senate-alexander-vs-ball',
#   'state': 'TN',
#   'title': '2014 Tennessee Senate: Alexander vs. Ball',
#   'topic': '2014-senate',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-tennessee-senate-alexander-vs-ball'},
#  {'election_date': '2014-11-04',
#   'estimates': [{'choice': 'Risch',
#     'first_name': 'Jim',
#     'incumbent': True,
#     'last_name': 'Risch',
#     'lead_confidence': 100.0,
#     'party': 'Rep',
#     'value': 57.7},
#    {'choice': 'Mitchell',
#     'first_name': 'Nels',
#     'incumbent': False,
#     'last_name': 'Mitchell',
#     'lead_confidence': 0.0,
#     'party': 'Dem',
#     'value': 29.2}],
#   'id': 543,
#   'last_updated': '2016-06-06T14:38:11.000Z',
#   'poll_count': 6,
#   'short_title': '2014 Idaho Senate',
#   'slug': '2014-idaho-senate-risch-vs-mitchell',
#   'state': 'ID',
#   'title': '2014 Idaho Senate: Risch vs. Mitchell',
#   'topic': '2014-senate',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-idaho-senate-risch-vs-mitchell'},
#  {'election_date': '2014-11-04',
#   'estimates': [{'choice': 'Booker',
#     'first_name': 'Cory',
#     'incumbent': True,
#     'last_name': 'Booker',
#     'lead_confidence': 100.0,
#     'party': 'Dem',
#     'value': 52.7},
#    {'choice': 'Bell',
#     'first_name': 'Jeff',
#     'incumbent': False,
#     'last_name': 'Bell',
#     'lead_confidence': 0.0,
#     'party': 'Rep',
#     'value': 37.4},
#    {'choice': 'Other',
#     'first_name': None,
#     'incumbent': False,
#     'last_name': None,
#     'lead_confidence': None,
#     'party': 'N/A',
#     'value': 0.76}],
#   'id': 538,
#   'last_updated': '2016-06-06T14:38:14.000Z',
#   'poll_count': 15,
#   'short_title': '2014 New Jersey Senate',
#   'slug': '2014-new-jersey-senate-bell-vs-booker',
#   'state': 'NJ',
#   'title': '2014 New Jersey Senate: Bell vs. Booker',
#   'topic': '2014-senate',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-new-jersey-senate-bell-vs-booker'},
#  {'election_date': '2014-11-04',
#   'estimates': [{'choice': 'Udall',
#     'first_name': 'Tom',
#     'incumbent': True,
#     'last_name': 'Udall',
#     'lead_confidence': 99.9,
#     'party': 'Dem',
#     'value': 52.1},
#    {'choice': 'Weh',
#     'first_name': 'Allen',
#     'incumbent': False,
#     'last_name': 'Weh',
#     'lead_confidence': 0.1,
#     'party': 'Rep',
#     'value': 39.6},
#    {'choice': 'Other',
#     'first_name': None,
#     'incumbent': False,
#     'last_name': None,
#     'lead_confidence': None,
#     'party': 'N/A',
#     'value': 1.0}],
#   'id': 536,
#   'last_updated': '2016-06-06T14:38:15.000Z',
#   'poll_count': 12,
#   'short_title': '2014 New Mexico Senate',
#   'slug': '2014-new-mexico-senate-weh-vs-udall',
#   'state': 'NM',
#   'title': '2014 New Mexico Senate: Weh vs. Udall',
#   'topic': '2014-senate',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-new-mexico-senate-weh-vs-udall'},
#  {'election_date': '2014-11-04',
#   'estimates': [{'choice': 'Inhofe',
#     'first_name': 'Jim',
#     'incumbent': True,
#     'last_name': 'Inhofe',
#     'lead_confidence': 100.0,
#     'party': 'Rep',
#     'value': 64.4},
#    {'choice': 'Silverstein',
#     'first_name': 'Matt',
#     'incumbent': False,
#     'last_name': 'Silverstein',
#     'lead_confidence': 0.0,
#     'party': 'Dem',
#     'value': 27.1},
#    {'choice': 'Other',
#     'first_name': None,
#     'incumbent': False,
#     'last_name': None,
#     'lead_confidence': None,
#     'party': 'N/A',
#     'value': 2.76}],
#   'id': 533,
#   'last_updated': '2016-06-06T14:38:18.000Z',
#   'poll_count': 8,
#   'short_title': '2014 Oklahoma Senate: Inhofe vs. Silverstein',
#   'slug': '2014-oklahoma-senate-inhofe-vs-silverstein',
#   'state': 'OK',
#   'title': '2014 Oklahoma Senate: Inhofe vs. Silverstein',
#   'topic': '2014-senate',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-oklahoma-senate-inhofe-vs-silverstein'},
#  {'election_date': '2014-11-04',
#   'estimates': [{'choice': 'Scott',
#     'first_name': 'Tim',
#     'incumbent': True,
#     'last_name': 'Scott',
#     'lead_confidence': 100.0,
#     'party': 'Rep',
#     'value': 55.1},
#    {'choice': 'Dickerson',
#     'first_name': 'Joyce',
#     'incumbent': False,
#     'last_name': 'Dickerson',
#     'lead_confidence': 0.0,
#     'party': 'Dem',
#     'value': 27.5}],
#   'id': 531,
#   'last_updated': '2016-06-06T14:38:19.000Z',
#   'poll_count': 6,
#   'short_title': '2014 South Carolina Senate: Scott vs. Dickerson',
#   'slug': '2014-south-carolina-senate-scott-vs-dickerson',
#   'state': 'SC',
#   'title': '2014 South Carolina Senate: Scott vs. Dickerson',
#   'topic': '2014-senate',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-south-carolina-senate-scott-vs-dickerson'},
#  {'election_date': '2014-11-04',
#   'estimates': [{'choice': 'Graham',
#     'first_name': 'Lindsey',
#     'incumbent': True,
#     'last_name': 'Graham',
#     'lead_confidence': 99.9,
#     'party': 'Rep',
#     'value': 47.6},
#    {'choice': 'Hutto',
#     'first_name': 'Brad',
#     'incumbent': False,
#     'last_name': 'Hutto',
#     'lead_confidence': 0.0,
#     'party': 'Dem',
#     'value': 29.5},
#    {'choice': 'Other',
#     'first_name': None,
#     'incumbent': False,
#     'last_name': None,
#     'lead_confidence': None,
#     'party': 'N/A',
#     'value': 10.0}],
#   'id': 530,
#   'last_updated': '2016-06-06T14:38:19.000Z',
#   'poll_count': 8,
#   'short_title': '2014 South Carolina Senate: Graham vs. Hutto',
#   'slug': '2014-south-carolina-senate-graham-vs-hutto',
#   'state': 'SC',
#   'title': '2014 South Carolina Senate: Graham vs. Hutto',
#   'topic': '2014-senate',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-south-carolina-senate-graham-vs-hutto'},
#  {'election_date': '2014-11-04',
#   'estimates': [{'choice': 'Cornyn',
#     'first_name': 'John',
#     'incumbent': True,
#     'last_name': 'Cornyn',
#     'lead_confidence': 100.0,
#     'party': 'Rep',
#     'value': 54.0},
#    {'choice': 'Alameel',
#     'first_name': 'David',
#     'incumbent': False,
#     'last_name': 'Alameel',
#     'lead_confidence': 0.0,
#     'party': 'Dem',
#     'value': 30.9},
#    {'choice': 'Other',
#     'first_name': None,
#     'incumbent': False,
#     'last_name': None,
#     'lead_confidence': None,
#     'party': 'N/A',
#     'value': 0.8}],
#   'id': 528,
#   'last_updated': '2016-06-06T14:38:20.000Z',
#   'poll_count': 10,
#   'short_title': '2014 Texas Senate',
#   'slug': '2014-texas-senate-cornyn-vs-alameel',
#   'state': 'TX',
#   'title': '2014 Texas Senate: Cornyn vs. Alameel',
#   'topic': '2014-senate',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-texas-senate-cornyn-vs-alameel'},
#  {'election_date': '2014-11-04',
#   'estimates': [{'choice': 'Franken',
#     'first_name': 'Al',
#     'incumbent': True,
#     'last_name': 'Franken',
#     'lead_confidence': 100.0,
#     'party': 'Dem',
#     'value': 51.5},
#    {'choice': 'McFadden',
#     'first_name': 'Mike',
#     'incumbent': False,
#     'last_name': 'McFadden',
#     'lead_confidence': 0.0,
#     'party': 'Rep',
#     'value': 39.9},
#    {'choice': 'Other',
#     'first_name': None,
#     'incumbent': False,
#     'last_name': None,
#     'lead_confidence': None,
#     'party': 'N/A',
#     'value': 4.87}],
#   'id': 523,
#   'last_updated': '2016-06-06T14:38:23.000Z',
#   'poll_count': 21,
#   'short_title': '2014 Minnesota Senate',
#   'slug': '2014-minnesota-senate-mcfadden-vs-franken',
#   'state': 'MN',
#   'title': '2014 Minnesota Senate: McFadden vs. Franken',
#   'topic': '2014-senate',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-minnesota-senate-mcfadden-vs-franken'},
#  {'election_date': '2014-11-04',
#   'estimates': [{'choice': 'Collins',
#     'first_name': 'Susan',
#     'incumbent': True,
#     'last_name': 'Collins',
#     'lead_confidence': 100.0,
#     'party': 'Rep',
#     'value': 61.1},
#    {'choice': 'Bellows',
#     'first_name': 'Shenna',
#     'incumbent': False,
#     'last_name': 'Bellows',
#     'lead_confidence': 0.0,
#     'party': 'Dem',
#     'value': 34.1},
#    {'choice': 'Other',
#     'first_name': None,
#     'incumbent': False,
#     'last_name': None,
#     'lead_confidence': None,
#     'party': 'N/A',
#     'value': 1.5}],
#   'id': 522,
#   'last_updated': '2016-06-06T14:38:23.000Z',
#   'poll_count': 16,
#   'short_title': '2014 Maine Senate',
#   'slug': '2014-maine-senate-collins-vs-bellows',
#   'state': 'ME',
#   'title': '2014 Maine Senate: Collins vs. Bellows',
#   'topic': '2014-senate',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-maine-senate-collins-vs-bellows'},
#  {'election_date': '2014-11-04',
#   'estimates': [{'choice': 'Rounds',
#     'first_name': 'Mike',
#     'incumbent': False,
#     'last_name': 'Rounds',
#     'lead_confidence': 99.9,
#     'party': 'Rep',
#     'value': 43.4},
#    {'choice': 'Weiland',
#     'first_name': 'Rick',
#     'incumbent': False,
#     'last_name': 'Weiland',
#     'lead_confidence': 0.0,
#     'party': 'Dem',
#     'value': 29.7},
#    {'choice': 'Pressler',
#     'first_name': 'Larry',
#     'incumbent': False,
#     'last_name': 'Pressler',
#     'lead_confidence': None,
#     'party': 'Ind',
#     'value': 17.7},
#    {'choice': 'Other',
#     'first_name': None,
#     'incumbent': False,
#     'last_name': None,
#     'lead_confidence': None,
#     'party': 'N/A',
#     'value': 1.65}],
#   'id': 511,
#   'last_updated': '2016-06-06T14:38:28.000Z',
#   'poll_count': 25,
#   'short_title': '2014 South Dakota Senate',
#   'slug': '2014-south-dakota-senate-rounds-vs-weiland',
#   'state': 'SD',
#   'title': '2014 South Dakota Senate: Rounds vs. Weiland',
#   'topic': '2014-senate',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-south-dakota-senate-rounds-vs-weiland'},
#  {'election_date': '2014-11-04',
#   'estimates': [{'choice': 'Sasse',
#     'first_name': 'Ben',
#     'incumbent': False,
#     'last_name': 'Sasse',
#     'lead_confidence': 100.0,
#     'party': 'Rep',
#     'value': 57.2},
#    {'choice': 'Domina',
#     'first_name': 'David',
#     'incumbent': False,
#     'last_name': 'Domina',
#     'lead_confidence': 0.0,
#     'party': 'Dem',
#     'value': 30.3}],
#   'id': 505,
#   'last_updated': '2016-06-06T14:38:32.000Z',
#   'poll_count': 6,
#   'short_title': '2014 Nebraska Senate: Sasse vs. Domina',
#   'slug': '2014-nebraska-senate-sasse-vs-domina',
#   'state': 'NE',
#   'title': '2014 Nebraska Senate: Sasse vs. Domina',
#   'topic': '2014-senate',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-nebraska-senate-sasse-vs-domina'},
#  {'election_date': '2014-11-04',
#   'estimates': [{'choice': 'Perdue',
#     'first_name': 'David',
#     'incumbent': False,
#     'last_name': 'Perdue',
#     'lead_confidence': 99.9,
#     'party': 'Rep',
#     'value': 47.4},
#    {'choice': 'Nunn',
#     'first_name': 'Michelle',
#     'incumbent': False,
#     'last_name': 'Nunn',
#     'lead_confidence': 0.0,
#     'party': 'Dem',
#     'value': 43.4},
#    {'choice': 'Swafford',
#     'first_name': 'Amanda',
#     'incumbent': False,
#     'last_name': 'Swafford',
#     'lead_confidence': None,
#     'party': 'Lib',
#     'value': 3.7},
#    {'choice': 'Other',
#     'first_name': None,
#     'incumbent': False,
#     'last_name': None,
#     'lead_confidence': None,
#     'party': 'N/A',
#     'value': 1.6}],
#   'id': 497,
#   'last_updated': '2016-07-08T16:29:13.000Z',
#   'poll_count': 51,
#   'short_title': '2014 Georgia Senate',
#   'slug': '2014-georgia-senate-perdue-vs-nunn',
#   'state': 'GA',
#   'title': '2014 Georgia Senate: Perdue vs. Nunn',
#   'topic': '2014-senate',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-georgia-senate-perdue-vs-nunn'},
#  {'election_date': '2014-11-04',
#   'estimates': [{'choice': 'Merkley',
#     'first_name': 'Jeff',
#     'incumbent': True,
#     'last_name': 'Merkley',
#     'lead_confidence': 100.0,
#     'party': 'Dem',
#     'value': 52.7},
#    {'choice': 'Wehby',
#     'first_name': 'Monica',
#     'incumbent': False,
#     'last_name': 'Wehby',
#     'lead_confidence': 0.0,
#     'party': 'Rep',
#     'value': 35.2},
#    {'choice': 'Other',
#     'first_name': None,
#     'incumbent': False,
#     'last_name': None,
#     'lead_confidence': None,
#     'party': 'N/A',
#     'value': 4.54}],
#   'id': 489,
#   'last_updated': '2016-06-06T14:38:40.000Z',
#   'poll_count': 19,
#   'short_title': '2014 Oregon Senate',
#   'slug': '2014-oregon-senate-wehby-vs-merkley',
#   'state': 'OR',
#   'title': '2014 Oregon Senate: Wehby vs. Merkley',
#   'topic': '2014-senate',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-oregon-senate-wehby-vs-merkley'},
#  {'election_date': '2014-11-04',
#   'estimates': [{'choice': 'Cochran',
#     'first_name': 'Thad',
#     'incumbent': True,
#     'last_name': 'Cochran',
#     'lead_confidence': 99.9,
#     'party': 'Rep',
#     'value': 44.2},
#    {'choice': 'Childers',
#     'first_name': 'Travis',
#     'incumbent': False,
#     'last_name': 'Childers',
#     'lead_confidence': 0.0,
#     'party': 'Dem',
#     'value': 26.7},
#    {'choice': 'Other',
#     'first_name': None,
#     'incumbent': False,
#     'last_name': None,
#     'lead_confidence': None,
#     'party': 'N/A',
#     'value': 9.0}],
#   'id': 469,
#   'last_updated': '2016-06-06T14:38:52.000Z',
#   'poll_count': 8,
#   'short_title': '2014 Mississippi Senate',
#   'slug': '2014-mississippi-senate-cochran-vs-childers',
#   'state': 'MS',
#   'title': '2014 Mississippi Senate: Cochran vs. Childers',
#   'topic': '2014-senate',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-mississippi-senate-cochran-vs-childers'},
#  {'election_date': '2014-11-04',
#   'estimates': [{'choice': 'Ernst',
#     'first_name': 'Joni',
#     'incumbent': False,
#     'last_name': 'Ernst',
#     'lead_confidence': 94.1,
#     'party': 'Rep',
#     'value': 48.1},
#    {'choice': 'Braley',
#     'first_name': 'Bruce',
#     'incumbent': False,
#     'last_name': 'Braley',
#     'lead_confidence': 5.9,
#     'party': 'Dem',
#     'value': 45.6},
#    {'choice': 'Other',
#     'first_name': None,
#     'incumbent': False,
#     'last_name': None,
#     'lead_confidence': None,
#     'party': 'N/A',
#     'value': 1.76}],
#   'id': 463,
#   'last_updated': '2016-07-08T16:29:30.000Z',
#   'poll_count': 55,
#   'short_title': '2014 Iowa Senate',
#   'slug': '2014-iowa-senate-ernst-vs-braley',
#   'state': 'IA',
#   'title': '2014 Iowa Senate: Ernst vs. Braley',
#   'topic': '2014-senate',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-iowa-senate-ernst-vs-braley'},
#  {'election_date': '2014-11-04',
#   'estimates': [{'choice': 'Sullivan',
#     'first_name': 'Dan',
#     'incumbent': False,
#     'last_name': 'Sullivan',
#     'lead_confidence': 99.8,
#     'party': 'Rep',
#     'value': 50.0},
#    {'choice': 'Begich',
#     'first_name': 'Mark',
#     'incumbent': True,
#     'last_name': 'Begich',
#     'lead_confidence': 0.2,
#     'party': 'Dem',
#     'value': 45.7},
#    {'choice': 'Other',
#     'first_name': None,
#     'incumbent': False,
#     'last_name': None,
#     'lead_confidence': None,
#     'party': 'N/A',
#     'value': 4.98}],
#   'id': 459,
#   'last_updated': '2016-06-06T14:38:57.000Z',
#   'poll_count': 35,
#   'short_title': '2014 Alaska Senate: Sullivan vs. Begich',
#   'slug': '2014-alaska-senate-sullivan-vs-begich',
#   'state': 'AK',
#   'title': '2014 Alaska Senate: Sullivan vs. Begich',
#   'topic': '2014-senate',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-alaska-senate-sullivan-vs-begich'},
#  {'election_date': '2014-11-04',
#   'estimates': [{'choice': 'Durbin',
#     'first_name': 'Dick',
#     'incumbent': True,
#     'last_name': 'Durbin',
#     'lead_confidence': 100.0,
#     'party': 'Dem',
#     'value': 51.6},
#    {'choice': 'Oberweis',
#     'first_name': 'Jim',
#     'incumbent': False,
#     'last_name': 'Oberweis',
#     'lead_confidence': 0.0,
#     'party': 'Rep',
#     'value': 38.7},
#    {'choice': 'Other',
#     'first_name': None,
#     'incumbent': False,
#     'last_name': None,
#     'lead_confidence': None,
#     'party': 'N/A',
#     'value': 3.12}],
#   'id': 457,
#   'last_updated': '2016-06-06T14:38:58.000Z',
#   'poll_count': 15,
#   'short_title': 'IL Senate: Oberweis vs. Durbin',
#   'slug': '2014-illinois-senate-oberweis-vs-durbin',
#   'state': 'IL',
#   'title': '2014 Illinois Senate: Oberweis vs. Durbin',
#   'topic': '2014-senate',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-illinois-senate-oberweis-vs-durbin'},
#  {'election_date': '2014-11-04',
#   'estimates': [{'choice': 'Gardner',
#     'first_name': 'Cory',
#     'incumbent': False,
#     'last_name': 'Gardner',
#     'lead_confidence': 93.2,
#     'party': 'Rep',
#     'value': 49.2},
#    {'choice': 'Udall',
#     'first_name': 'Mark',
#     'incumbent': True,
#     'last_name': 'Udall',
#     'lead_confidence': 6.8,
#     'party': 'Dem',
#     'value': 47.3},
#    {'choice': 'Other',
#     'first_name': None,
#     'incumbent': False,
#     'last_name': None,
#     'lead_confidence': None,
#     'party': 'N/A',
#     'value': '4.892640752232218'},
#    {'choice': 'Undecided',
#     'first_name': None,
#     'incumbent': False,
#     'last_name': None,
#     'lead_confidence': None,
#     'party': 'N/A',
#     'value': 3.5}],
#   'id': 453,
#   'last_updated': '2016-08-15T15:22:09.000Z',
#   'poll_count': 54,
#   'short_title': '2014 Colorado Senate',
#   'slug': '2014-colorado-senate-gardner-vs-udall',
#   'state': 'CO',
#   'title': '2014 Colorado Senate: Gardner vs. Udall',
#   'topic': '2014-senate',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-colorado-senate-gardner-vs-udall'},
#  {'election_date': '2014-11-04',
#   'estimates': [{'choice': 'Warner',
#     'first_name': 'Mark',
#     'incumbent': True,
#     'last_name': 'Warner',
#     'lead_confidence': 99.9,
#     'party': 'Dem',
#     'value': 50.3},
#    {'choice': 'Gillespie',
#     'first_name': 'Ed',
#     'incumbent': False,
#     'last_name': 'Gillespie',
#     'lead_confidence': 0.0,
#     'party': 'Rep',
#     'value': 38.7},
#    {'choice': 'Sarvis',
#     'first_name': 'Robert',
#     'incumbent': False,
#     'last_name': 'Sarvis',
#     'lead_confidence': None,
#     'party': 'Lib',
#     'value': 2.0}],
#   'id': 444,
#   'last_updated': '2016-06-06T14:39:10.000Z',
#   'poll_count': 22,
#   'short_title': '2014 Virginia Senate',
#   'slug': '2014-virginia-senate-gillespie-vs-warner',
#   'state': 'VA',
#   'title': '2014 Virginia Senate: Gillespie vs. Warner',
#   'topic': '2014-senate',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-virginia-senate-gillespie-vs-warner'},
#  {'election_date': '2014-11-04',
#   'estimates': [{'choice': 'Hagan',
#     'first_name': 'Kay',
#     'incumbent': True,
#     'last_name': 'Hagan',
#     'lead_confidence': 69.7,
#     'party': 'Dem',
#     'value': 46.3},
#    {'choice': 'Tillis',
#     'first_name': 'Thom',
#     'incumbent': False,
#     'last_name': 'Tillis',
#     'lead_confidence': 30.3,
#     'party': 'Rep',
#     'value': 45.7},
#    {'choice': 'Haugh',
#     'first_name': 'Sean',
#     'incumbent': False,
#     'last_name': 'Haugh',
#     'lead_confidence': None,
#     'party': 'Lib',
#     'value': 4.9},
#    {'choice': 'Other',
#     'first_name': None,
#     'incumbent': False,
#     'last_name': None,
#     'lead_confidence': None,
#     'party': 'N/A',
#     'value': 1.85}],
#   'id': 438,
#   'last_updated': '2016-07-08T16:29:46.000Z',
#   'poll_count': 76,
#   'short_title': '2014 North Carolina Senate',
#   'slug': '2014-north-carolina-senate-tillis-vs-hagan',
#   'state': 'NC',
#   'title': '2014 North Carolina Senate: Tillis vs. Hagan',
#   'topic': '2014-senate',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-north-carolina-senate-tillis-vs-hagan'},
#  {'election_date': '2014-11-04',
#   'estimates': [{'choice': 'Capito',
#     'first_name': 'Shelley',
#     'incumbent': False,
#     'last_name': 'Moore Capito',
#     'lead_confidence': 100.0,
#     'party': 'Rep',
#     'value': 53.5},
#    {'choice': 'Tennant',
#     'first_name': 'Natalie',
#     'incumbent': False,
#     'last_name': 'Tennant',
#     'lead_confidence': 0.0,
#     'party': 'Dem',
#     'value': 35.8},
#    {'choice': 'Undecided',
#     'first_name': None,
#     'incumbent': False,
#     'last_name': None,
#     'lead_confidence': None,
#     'party': 'N/A',
#     'value': 10.7},
#    {'choice': 'Other',
#     'first_name': None,
#     'incumbent': False,
#     'last_name': None,
#     'lead_confidence': None,
#     'party': 'N/A',
#     'value': '0.27212787062756977'}],
#   'id': 418,
#   'last_updated': '2016-09-02T12:37:09.000Z',
#   'poll_count': 14,
#   'short_title': '2014 West Virginia Senate',
#   'slug': '2014-west-virginia-senate-capito-vs-tennant',
#   'state': 'WV',
#   'title': '2014 West Virginia Senate: Capito vs. Tennant',
#   'topic': '2014-senate',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-west-virginia-senate-capito-vs-tennant'},
#  {'election_date': '2014-11-04',
#   'estimates': [{'choice': 'Shaheen',
#     'first_name': 'Jeanne',
#     'incumbent': True,
#     'last_name': 'Shaheen',
#     'lead_confidence': 89.6,
#     'party': 'Dem',
#     'value': 47.6},
#    {'choice': 'Brown',
#     'first_name': 'Scott',
#     'incumbent': False,
#     'last_name': 'Brown',
#     'lead_confidence': 10.4,
#     'party': 'Rep',
#     'value': 46.2},
#    {'choice': 'Other',
#     'first_name': None,
#     'incumbent': False,
#     'last_name': None,
#     'lead_confidence': None,
#     'party': 'N/A',
#     'value': 1.26}],
#   'id': 414,
#   'last_updated': '2016-07-08T16:30:01.000Z',
#   'poll_count': 62,
#   'short_title': '2014 New Hampshire Senate',
#   'slug': '2014-new-hampshire-senate-brown-vs-shaheen',
#   'state': 'NH',
#   'title': '2014 New Hampshire Senate: Brown vs. Shaheen',
#   'topic': '2014-senate',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-new-hampshire-senate-brown-vs-shaheen'},
#  {'election_date': '2014-12-06',
#   'estimates': [{'choice': 'Cassidy',
#     'first_name': 'Bill',
#     'incumbent': False,
#     'last_name': 'Cassidy',
#     'lead_confidence': 100.0,
#     'party': 'Rep',
#     'value': 55.5},
#    {'choice': 'Landrieu',
#     'first_name': 'Mary',
#     'incumbent': True,
#     'last_name': 'Landrieu',
#     'lead_confidence': 0.0,
#     'party': 'Dem',
#     'value': 40.7}],
#   'id': 411,
#   'last_updated': '2016-06-06T14:39:31.000Z',
#   'poll_count': 41,
#   'short_title': '2014 Louisiana Senate',
#   'slug': '2014-louisiana-senate-cassidy-vs-landrieu',
#   'state': 'LA',
#   'title': '2014 Louisiana Senate: Cassidy vs. Landrieu',
#   'topic': '2014-senate',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-louisiana-senate-cassidy-vs-landrieu'},
#  {'election_date': '2014-11-04',
#   'estimates': [{'choice': 'Peters',
#     'first_name': 'Gary',
#     'incumbent': False,
#     'last_name': 'Peters',
#     'lead_confidence': 100.0,
#     'party': 'Dem',
#     'value': 51.6},
#    {'choice': 'Land',
#     'first_name': 'Terri Lynn',
#     'incumbent': False,
#     'last_name': 'Land',
#     'lead_confidence': 0.0,
#     'party': 'Rep',
#     'value': 39.8},
#    {'choice': 'Other',
#     'first_name': None,
#     'incumbent': False,
#     'last_name': None,
#     'lead_confidence': None,
#     'party': 'N/A',
#     'value': 3.98}],
#   'id': 407,
#   'last_updated': '2016-07-08T16:30:11.000Z',
#   'poll_count': 67,
#   'short_title': '2014 Michigan Senate',
#   'slug': '2014-michigan-senate-land-vs-peters',
#   'state': 'MI',
#   'title': '2014 Michigan Senate: Land vs. Peters',
#   'topic': '2014-senate',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-michigan-senate-land-vs-peters'},
#  {'election_date': '2014-11-04',
#   'estimates': [{'choice': 'Cotton',
#     'first_name': 'Tom',
#     'incumbent': False,
#     'last_name': 'Cotton',
#     'lead_confidence': 100.0,
#     'party': 'Rep',
#     'value': 51.7},
#    {'choice': 'Pryor',
#     'first_name': 'Mark',
#     'incumbent': True,
#     'last_name': 'Pryor',
#     'lead_confidence': 0.0,
#     'party': 'Dem',
#     'value': 45.6},
#    {'choice': 'Other',
#     'first_name': None,
#     'incumbent': False,
#     'last_name': None,
#     'lead_confidence': None,
#     'party': 'N/A',
#     'value': '3.8016113722650173'},
#    {'choice': 'Undecided',
#     'first_name': None,
#     'incumbent': False,
#     'last_name': None,
#     'lead_confidence': None,
#     'party': 'N/A',
#     'value': 2.7}],
#   'id': 406,
#   'last_updated': '2016-08-11T21:02:10.000Z',
#   'poll_count': 61,
#   'short_title': '2014 Arkansas Senate',
#   'slug': '2014-arkansas-senate-cotton-vs-pryor',
#   'state': 'AR',
#   'title': '2014 Arkansas Senate: Cotton vs. Pryor',
#   'topic': '2014-senate',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-arkansas-senate-cotton-vs-pryor'},
#  {'election_date': '2014-11-04',
#   'estimates': [{'choice': 'McConnell',
#     'first_name': 'Mitch',
#     'incumbent': True,
#     'last_name': 'McConnell',
#     'lead_confidence': 100.0,
#     'party': 'Rep',
#     'value': 50.1},
#    {'choice': 'Grimes',
#     'first_name': 'Alison Lundergan',
#     'incumbent': False,
#     'last_name': 'Grimes',
#     'lead_confidence': 0.0,
#     'party': 'Dem',
#     'value': 44.1},
#    {'choice': 'Other',
#     'first_name': None,
#     'incumbent': False,
#     'last_name': None,
#     'lead_confidence': None,
#     'party': 'N/A',
#     'value': 2.9}],
#   'id': 402,
#   'last_updated': '2016-07-08T16:30:15.000Z',
#   'poll_count': 57,
#   'short_title': '2014 Kentucky Senate',
#   'slug': '2014-kentucky-senate-mcconnell-vs-grimes',
#   'state': 'KY',
#   'title': '2014 Kentucky Senate: McConnell vs. Grimes',
#   'topic': '2014-senate',
#   'url': 'http://elections.huffingtonpost.com/pollster/2014-kentucky-senate-mcconnell-vs-grimes'}]

# %% [markdown]
# ** Your answer here: **

# %% [markdown]
# #### Problem 1(c)
#
# Create a dictionary of pandas DataFrames called `polls` keyed by the name of the election (a string). Each value in the dictionary should contain the polls for one of the races.

# %%
def build_frame(url):
    """
    Returns a pandas DataFrame object containing
    the data returned from the given url
    """
    source = requests.get(url).text
    
    # Use StringIO because pd.DataFrame.from_csv requires .read() method
    s = io.StringIO(source)
    
    return pd.DataFrame.from_csv(s, index_col=None).convert_objects(
            convert_dates="coerce", convert_numeric=True)

# %%
# Makes a dictionary of pandas DataFrames keyed on election string.
polls = dict((election['slug'], build_frame(election['url']+'.csv')) for election in editinfo)
polls
# Out:
# C:\Users\Wolf\Anaconda3\lib\site-packages\ipykernel\__main__.py:12: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
# {'2014-alaska-senate-sullivan-vs-begich':                                             Pollster Start Date   End Date  \
#  0                                            PPP (D) 2014-11-01 2014-11-02
#  1                                          Rasmussen 2014-10-27 2014-10-30
#  2                 Moore (R-Sullivan For U.S. Senate) 2014-10-26 2014-10-28
#  3                                         Ivan Moore 2014-10-24 2014-10-26
#  4                                     CBS/NYT/YouGov 2014-10-16 2014-10-23
#  5   Harstad (D-Senate Majority PAC/Put Alaska First) 2014-10-18 2014-10-22
#  6                                         Hellenthal 2014-10-15 2014-10-21
#  7                                          Rasmussen 2014-10-08 2014-10-12
#  8                                                FOX 2014-10-04 2014-10-07
#  9                                                CNN 2014-10-01 2014-10-06
#  10              Hickman (D-Consumer Energy Alliance) 2014-09-26 2014-10-02
#  11                                    CBS/NYT/YouGov 2014-09-20 2014-10-01
#  12                                         Rasmussen 2014-09-23 2014-09-24
#  13                                        Hellenthal 2014-09-12 2014-09-24
#  14                                           PPP (D) 2014-09-18 2014-09-21
#  15                   Dittman (R-Chamber of Commerce) 2014-09-14 2014-09-17
#  16                  Hays Research (D-Alaska AFL-CIO) 2014-09-13 2014-09-14
#  17                   Harstad (D-Senate Majority PAC) 2014-09-07 2014-09-10
#  8        Live Phone    46.0   39.0       11.0
#  9        Live Phone    42.0   45.0        9.0
#  10         Internet    45.0   41.0       13.0
#  11       IVR/Online    47.0   40.0        NaN
#  12       Live Phone    43.0   45.0        7.0
#  13       IVR/Online    43.0   38.0       13.0
#  14       Live Phone    43.0   46.0       11.0
#  15  Automated Phone    47.0   43.0        8.0
#  16       Live Phone    43.0   45.0       12.0
#  17       Live Phone    45.0   40.0        9.0
#  18       Live Phone    49.0   47.0        4.0
#  19         Internet    43.0   39.0       16.0
#  20       IVR/Online    43.0   44.0        NaN
#  21       Live Phone    41.0   46.0        9.0
#  22       IVR/Online    41.0   39.0       14.0
#  23   IVR/Live Phone    44.0   42.0        7.0
#  24       Live Phone    46.0   48.0        NaN
#  25         Internet    50.0   46.0        3.0
#  26       Live Phone    39.0   45.0        NaN
#  27  Automated Phone    51.0   44.0        NaN
#  28  Automated Phone    47.0   43.0       10.0
#  29       Live Phone    47.0   40.0        NaN
#  ..              ...     ...    ...        ...
#  31  Automated Phone    49.0   45.0        4.0
#  32       Live Phone    46.0   41.0        7.0
#  33       IVR/Online    47.0   43.0        NaN
#  34       Live Phone    42.0   40.0       12.0
#  35       Live Phone    40.0   51.0        7.0
#  36  Automated Phone    42.0   43.0       16.0
#  37  Automated Phone    46.0   43.0        7.0
#  38       Live Phone    36.0   46.0       15.0
#  39       Live Phone    39.0   39.0       22.0
#  40       Live Phone    38.0   48.0       13.0
#  41   IVR/Live Phone    43.0   46.0        8.0
#  42       Live Phone    45.0   48.0        7.0
#  43       Live Phone    37.0   40.0       14.0
#  44  Automated Phone    46.0   42.0       13.0
#  45       IVR/Online    45.0   40.0        NaN
#  46       Live Phone    42.0   36.0       22.0
#  47  Automated Phone    44.0   44.0       12.0
#  48       Live Phone    48.0   41.0       11.0
#  49  Automated Phone    42.0   41.0       18.0
#  50       Live Phone    45.0   41.0       15.0
#  51       Live Phone    37.0   36.0        NaN
#  52  Automated Phone    41.0   44.0       15.0
#  53  Automated Phone    41.0   42.0       17.0
#  54  Automated Phone    42.0   45.0       13.0
#  55       Live Phone    43.0   45.0        NaN
#  56  Automated Phone    43.0   41.0       16.0
#  57       Live Phone    44.0   42.0       14.0
#  58       Live Phone    35.0   43.0       21.0
#  59       Live Phone    40.0   41.0       19.0
#  60       Live Phone    43.0   35.0       22.0
#
#                                           Pollster URL  \
#  0   http://elections.huffingtonpost.com/pollster/p...
#  1   http://elections.huffingtonpost.com/pollster/p...
#  2   http://elections.huffingtonpost.com/pollster/p...
#  3   http://elections.huffingtonpost.com/pollster/p...
#  4   http://elections.huffingtonpost.com/pollster/p...
#  5   http://elections.huffingtonpost.com/pollster/p...
#  6   http://elections.huffingtonpost.com/pollster/p...
#  7   http://elections.huffingtonpost.com/pollster/p...
#  8   http://elections.huffingtonpost.com/pollster/p...
#  9   http://elections.huffingtonpost.com/pollster/p...
#  10  http://elections.huffingtonpost.com/pollster/p...
#  11  http://elections.huffingtonpost.com/pollster/p...
#  12  http://elections.huffingtonpost.com/pollster/p...
#  13  http://elections.huffingtonpost.com/pollster/p...
#  14  http://elections.huffingtonpost.com/pollster/p...
#  15  http://elections.huffingtonpost.com/pollster/p...
#  16  http://elections.huffingtonpost.com/pollster/p...
#  17  http://elections.huffingtonpost.com/pollster/p...
#  18  http://elections.huffingtonpost.com/pollster/p...
#  19  http://elections.huffingtonpost.com/pollster/p...
#  20  http://elections.huffingtonpost.com/pollster/p...
#  21  http://elections.huffingtonpost.com/pollster/p...
#  22  http://elections.huffingtonpost.com/pollster/p...
#  23  http://elections.huffingtonpost.com/pollster/p...
#  24  http://elections.huffingtonpost.com/pollster/p...
#  25  http://elections.huffingtonpost.com/pollster/p...
#  26  http://elections.huffingtonpost.com/pollster/p...
#  27  http://elections.huffingtonpost.com/pollster/p...
#  28  http://elections.huffingtonpost.com/pollster/p...
#  29  http://elections.huffingtonpost.com/pollster/p...
#  ..                                                ...
#  31  http://elections.huffingtonpost.com/pollster/p...
#  32  http://elections.huffingtonpost.com/pollster/p...
#  33  http://elections.huffingtonpost.com/pollster/p...
#  34  http://elections.huffingtonpost.com/pollster/p...
#  35  http://elections.huffingtonpost.com/pollster/p...
#  36  http://elections.huffingtonpost.com/pollster/p...
#  37  http://elections.huffingtonpost.com/pollster/p...
#  38  http://elections.huffingtonpost.com/pollster/p...
://www.publicpolicypolling.com/pdf/2014/PP...     Pollster
#  37  http://big.assets.huffingtonpost.com/Magellan0...      Sponsor
#  38  http://www.nytimes.com/interactive/2014/04/23/...  Nonpartisan
#  39  http://www.americancrossroads.org/wp-content/u...      Sponsor
#  40  http://big.assets.huffingtonpost.com/GARNQuest...     Pollster
#  41  http://talkbusiness.net/2014/04/pryor-holds-sm...  Nonpartisan
#  42  http://images.politico.com/global/2014/04/14/s...      Sponsor
#  43  http://buildkxlnow.org/wp/wp-content/uploads/2...     Pollster
#  44  http://www.thecitywire.com/sites/default/files...     Pollster
#  45  http://www.rasmussenreports.com/public_content...  Nonpartisan
#  46  http://images.politico.com/global/2014/02/06/a...      Sponsor
#  47  http://www.publicpolicypolling.com/pdf/2013/Ar...      Sponsor
#  48  http://images.politico.com/global/2013/12/09/c...      Sponsor
#  49  http://www.thecitywire.com/node/30242#.UwaEl0J...     Pollster
#  50  http://www.tomcotton.com/wp-content/uploads/20...      Sponsor
#  51                      http://plsc.uark.edu/7129.php  Nonpartisan
#  52  http://www.publicpolicypolling.com/pdf/2013/Se...      Sponsor
#  53  http://talkbusiness.net/2013/10/asa-still-lead...  Nonpartisan
#  54  http://images.politico.com/global/2013/10/14/a...      Sponsor
#  55  http://freebeacon.com/tom-cotton-in-dead-heat-...      Sponsor
#  56  http://conservativeintel.com/86-conservative-i...      Sponsor
#  57  http://images.politico.com/global/2013/08/11/a...      Sponsor
#  58  http://www.scribd.com/doc/158212312/AR-Sen-Cla...      Sponsor
#  59  http://www.senateconservatives.com/site/post/2...      Sponsor
#  60  http://www.clubforgrowth.org/perm/pr/?postID=1200     Pollster
#
#     Affiliation  Question Text  Question Iteration
#  0          Dem            NaN                   1
#  1         None            NaN                   1
#  2         None            NaN                   1
#  3          Dem            NaN                   1
#  4         None            NaN                   1
#  5         None            NaN                   1
#  6         None            NaN                   1
#  7         None            NaN                   1
#  8         None            NaN                   1
#  9          Dem            NaN                   1
#  10        None            NaN                   1
#  11        None            NaN                   1
#  12        None            NaN                   1
#  13         Dem            NaN                   1
#  14         Dem            NaN                   1
#  15        None            NaN                   1
#  16         Dem            NaN                   1
#  17        None            NaN                   1
#  18        None            NaN                   1
#  19        None            NaN                   1
#  20        None            NaN                   1
#  21         Dem            NaN                   1
#  22         Dem            NaN                   1
#  23        None            NaN                   1
#  24         Dem            NaN                   1
#  25        None            NaN                   1
#  26         Dem            NaN                   1
#  27        None            NaN                   1
#  28         Rep            NaN                   1
#  29         Rep            NaN                   1
#  ..         ...            ...                 ...
#  31         Rep            NaN                   1
#  32         Rep            NaN                   1
#  33        None            NaN                   1
#  34         Rep            NaN                   1
#  35        None            NaN                   1
#  36         Dem            NaN                   1
#  37         Rep            NaN                   1
#  38        None            NaN                   1
#  39         Rep            NaN                   1
#  40         Dem            NaN                   1
#  41        None            NaN                   1
#  42         Dem            NaN                   1
#  43         Dem            NaN                   1
#  44         Rep            NaN                   1
#  45        None            NaN                   1
#  46         Rep            NaN                   1
#  47         Dem            NaN                   1
#  48         Rep            NaN                   1
#  49         Rep            NaN                   1
#  50         Rep            NaN                   1
#  51        None            NaN                   1
#  52         Dem            NaN                   1
#  53        None            NaN                   1
#  54         Rep            NaN                   1
#  55         Rep            NaN                   1
#  56         Rep            NaN                   1
#  57         Rep            NaN                   1
#  58         Dem            NaN                   1
#  59         Rep            NaN                   1
#  60         Rep            NaN                   1
#
#  [61 rows x 16 columns],
#  '2014-colorado-senate-gardner-vs-udall':                                           Pollster Start Date   End Date  \
#  0                                          PPP (D) 2014-11-01 2014-11-02
#  10  2014-09-07 17:15:48                    1635      Likely Voters
#  11  2014-08-06 22:13:01                     804      Likely Voters
#  12  2014-07-29 17:13:20                    2047      Likely Voters
#  13  2014-07-23 16:03:57                     556  Registered Voters
#  14  2014-06-13 16:09:08                    1000      Likely Voters
#  15  2014-04-08 16:46:50                     689      Likely Voters
#  16  2014-03-27 14:49:39                    1288  Registered Voters
#  17  2014-03-04 16:39:52                     707  Registered Voters
#  18  2014-02-13 19:47:31                     936      Likely Voters
#  19  2014-01-23 17:40:01                    1023  Registered Voters
#  20  2014-01-23 16:54:24                    1000      Likely Voters
#  21  2014-01-21 19:26:59                     553  Registered Voters
#
#                 Mode  Warner  Gillespie  Undecided  \
#  0        Live Phone    51.0       44.0        3.0
#  1        Live Phone    47.0       35.0       15.0
#  2          Internet    49.0       39.0       11.0
#  3        Live Phone    47.0       37.0       10.0
#  4        Live Phone    51.0       39.0        7.0
#  5          Internet    51.0       39.0        9.0
#  6        IVR/Online    48.0       35.0       12.0
#  7        Live Phone    48.0       39.0        7.0
#  8        Live Phone    46.0       27.0       22.0
#  9        Live Phone    53.0       31.0       11.0
#  10         Internet    51.0       39.0        9.0
#  11       Live Phone    53.0       28.0       14.0
#  12         Internet    53.0       43.0        2.0
#  13       Live Phone    47.0       22.0       25.0
#  14       IVR/Online    53.0       36.0        9.0
#  15  Automated Phone    49.0       35.0       16.0
#  16       Live Phone    46.0       31.0       17.0
#  17       Live Phone    56.0       29.0       14.0
#  18  Automated Phone    44.0       38.0       18.0
#  19       Live Phone    50.0       30.0       18.0
#  20       IVR/Online    51.0       37.0        9.0
#  21       Live Phone    50.0       21.0       26.0
#
#                                           Pollster URL  \
#  0   http://elections.huffingtonpost.com/pollster/p...
#  1   http://elections.huffingtonpost.com/pollster/p...
#  2   http://elections.huffingtonpost.com/pollster/p...
#  3   http://elections.huffingtonpost.com/pollster/p...
#  4   http://elections.huffingtonpost.com/pollster/p...
#  5   http://elections.huffingtonpost.com/pollster/p...
#  6   http://elections.huffingtonpost.com/pollster/p...
#  7   http://elections.huffingtonpost.com/pollster/p...
#  8   http://elections.huffingtonpost.com/pollster/p...
#  9   http://elections.huffingtonpost.com/pollster/p...
#  10  http://elections.huffingtonpost.com/pollster/p...
#  11  http://elections.huffingtonpost.com/pollster/p...
#  12  http://elections.huffingtonpost.com/pollster/p...
#  13  http://elections.huffingtonpost.com/pollster/p...
#  14  http://elections.huffingtonpost.com/pollster/p...
#  15  http://elections.huffingtonpost.com/pollster/p...
#  16  http://elections.huffingtonpost.com/pollster/p...
#  17  http://elections.huffingtonpost.com/pollster/p...
#  18  http://elections.huffingtonpost.com/pollster/p...
#  19  http://elections.huffingtonpost.com/pollster/p...
#  20  http://elections.huffingtonpost.com/pollster/p...
#  21  http://elections.huffingtonpost.com/pollster/p...
#
#                                             Source URL     Partisan  \
#  0   http://cnu.edu/cpp/pdf/oct%2031%202014%20repor...  Nonpartisan
#  1   http://roanoke.edu/A-Z_Index/Institute_for_Pol...  Nonpartisan
#  2   http://today.yougov.com/news/2014/09/07/senate...  Nonpartisan
#  3   http://www.umw.edu/news/files/2014/10/2014-UMW...  Nonpartisan
#  4   http://cnu.edu/cpp/pdf/sept%2010%202014%20repo...  Nonpartisan
#  5   https://today.yougov.com/news/2014/09/07/battl...  Nonpartisan
#  6   http://www.publicpolicypolling.com/pdf/2014/PP...     Pollster
#  7   http://www.quinnipiac.edu/images/polling/va/va...  Nonpartisan
#  8   http://roanoke.edu/A-Z_Index/Institute_for_Pol...  Nonpartisan
#  9   http://cnu.edu/cpp/pdf/sept%2010%202014%20repo...  Nonpartisan
#  10  https://today.yougov.com/news/2014/09/07/battl...  Nonpartisan
#  11  http://www.hamptonu.edu/cpp/polls/201407_va_se...  Nonpartisan
#  12  http://mobile.nytimes.com/2014/07/28/upshot/ex...  Nonpartisan
#  13  http://roanoke.edu/News_and_Events/News_Archiv...  Nonpartisan
#  14  hhttp://www.rasmussenreports.com/public_conten...  Nonpartisan
#  15  http://www.scribd.com/doc/216793874/Virginia-M...      Sponsor
#  16  http://www.quinnipiac.edu/institutes-and-cente...  Nonpartisan
#  17  http://www.siena.edu/uploadedfiles/home/parent...  Nonpartisan
#  18  http://images.politico.com/global/2014/02/11/a...      Sponsor
#  19  http://big.assets.huffingtonpost.com/WasonCent...  Nonpartisan
#  20  http://www.rasmussenreports.com/public_content...  Nonpartisan
#  21  http://roanoke.edu/News_and_Events/News_Archiv...  Nonpartisan
#
#     Affiliation  Question Text  Question Iteration
#  0         None            NaN                   1
#  1         None            NaN                   1
#  2         None            NaN                   1
#  
http://www.rasmussenreports.com/public_content...  Nonpartisan
#  9   http://www.rasmussenreports.com/public_content...  Nonpartisan
#  10         http://www.wvgazette.com/News/201402140102      Sponsor
#  11  http://images.politico.com/global/2013/10/14/w...      Sponsor
#  12  http://www.publicpolicypolling.com/pdf/2013/PP...     Pollster
#  13  http://thewestvirginiapoll.com/wp-content/uplo...  Nonpartisan
#
#     Affiliation  Question Text  Question Iteration
#  0         None            NaN                   1
#  1         None            NaN                   1
#  2         None            NaN                   1
#  3         None            NaN                   1
#  4         None            NaN                   1
#  5         None            NaN                   1
#  6         None            NaN                   1
#  7         None            NaN                   1
#  8         None            NaN                   1
#  9         None            NaN                   1
#  10         Dem            NaN                   1
#  11         Rep            NaN                   1
#  12         Dem            NaN                   1
#  13        None            NaN                   1  ,
#  '2014-wyoming-senate':          Pollster Start Date   End Date Entry Date/Time (ET)  \
#  0  CBS/NYT/YouGov 2014-10-16 2014-10-23  2014-10-26 15:00:29
#  1  CBS/NYT/YouGov 2014-09-20 2014-10-01  2014-10-05 16:17:20
#  2  CBS/NYT/YouGov 2014-08-18 2014-09-02  2014-09-07 17:19:53
#  3       Rasmussen 2014-08-20 2014-08-21  2014-08-22 18:26:56
#  4  CBS/NYT/YouGov 2014-07-05 2014-07-24  2014-07-29 17:35:45
#
#     Number of Observations     Population        Mode  Hardy  Enzi  Undecided  \
#  0                     258  Likely Voters    Internet   27.0  67.0        6.0
#  1                     264  Likely Voters    Internet   17.0  75.0        6.0
#  2                     350  Likely Voters    Internet   21.0  66.0        8.0
#  3                     700  Likely Voters  IVR/Online   27.0  63.0        5.0
#  4                     410  Likely Voters    Internet   23.0  68.0        4.0
#
#     Other                                       Pollster URL  \
#  0    0.0  http://elections.huffingtonpost.com/pollster/p...
#  1    2.0  http://elections.huffingtonpost.com/pollster/p...
#  2    4.0  http://elections.huffingtonpost.com/pollster/p...
#  3    4.0  http://elections.huffingtonpost.com/pollster/p...
#  4    5.0  http://elections.huffingtonpost.com/pollster/p...
#
#                                            Source URL     Partisan Affiliation  \
#  0  http://today.yougov.com/news/2014/09/07/senate...  Nonpartisan        None
#  1  https://today.yougov.com/news/2014/09/07/battl...  Nonpartisan        None
#  2  https://today.yougov.com/news/2014/09/07/battl...  Nonpartisan        None
#  3  http://www.rasmussenreports.com/public_content...  Nonpartisan        None
#  4  http://mobile.nytimes.com/2014/07/28/upshot/ex...  Nonpartisan        None
#
#     Question Text  Question Iteration
#  0            NaN                   1
#  1            NaN                   1
#  2            NaN                   1
#  3            NaN                   1
#  4            NaN                   1  }

# %% [markdown]
# #### Problem 1(d)
#
# Now create a master table information containing information about each race. Create a pandas DataFrame called `candidates` with rows containing information about each race. The `candidates` DataFrame should have the following columns:
#
# 1. `State` = the state where the race is being held
# 2. `R` = name of republican candidate
# 3. `D` = name of non-republican candidate (Democrate or Independent)
# 4. `incumbent` = R, D or NA
#
# **Hint**: You will need a considerable amount of data wrangling for this.

# %%
df = pd.DataFrame([ele['state'] for ele in editinfo])
df.head()
# Out:
#     0
# 0  DE
# 1  MA
# 2  RI
# 3  MT
# 4  OK

# %%
cands = [ele['estimates'] for ele in editinfo]
cands
# Out:
# [[{'choice': 'Coons',
#    'first_name': 'Chris',
#    'incumbent': True,
#    'last_name': 'Coons',
#    'lead_confidence': 99.9,
#    'party': 'Dem',
#    'value': 56.0},
#   {'choice': 'Wade',
#    'first_name': 'Kevin',
#    'incumbent': False,
#    'last_name': 'Wade',
#    'lead_confidence': 0.0,
#    'party': 'Rep',
#    'value': 34.0}],
#  [{'choice': 'Markey',
#    'first_name': 'Ed',
#    'incumbent': True,
#    'last_name': 'Markey',
#    'lead_confidence': 99.9,
#    'party': 'Dem',
#    'value': 54.1},
#   {'choice': 'Herr',
#    'first_name': 'Brian',
#    'incumbent': False,
#    'last_name': 'Herr',
#    'lead_confidence': 0.0,
#    'party': 'Rep',
#    'value': 33.4},
#   {'choice': 'Other',
#    'first_name': None,
#    'incumbent': False,
#    'last_name': None,
#    'lead_confidence': None,
#    'party': 'N/A',
#    'value': 0.18}],
#  [],
#  [{'choice': 'Daines',
#    'first_name': 'Steve',
#    'incumbent': False,
#    'last_name': 'Daines',
#    'lead_confidence': 99.9,
#    'party': 'Rep',
#    'value': 53.8},
#   {'choice': 'Curtis',
#    'first_name': 'Amanda',
#    'incumbent': False,
#    'last_name': 'Curtis',
#    'lead_confidence': 0.0,
#    'party': 'Dem',
#    'value': 36.1}],
#  [{'choice': 'Lankford',
#    'first_name': 'James',
#    'incumbent': False,
#    'last_name': 'Lankford',
#    'lead_confidence': 100.0,
#    'party': 'Rep',
#    'value': 62.4},
#   {'choice': 'Johnson',
#    'first_name': 'Connie',
#    'incumbent': False,
#    'last_name': 'Johnson',
#    'lead_confidence': 0.0,
#    'party': 'Dem',
#    'value': 28.6},
#   {'choice': 'Other',
#    'first_name': None,
#    'incumbent': False,
#    'last_name': None,
#    'lead_confidence': None,
#    'party': 'N/A',
#    'value': 2.3}],
#  [{'choice': 'Schatz',
#    'first_name': 'Brian',
#    'incumbent': True,
#    'last_name': 'Schatz',
#    'lead_confidence': 100.0,
#    'party': 'Dem',
#    'value': 67.9},
#   {'choice': 'Cavasso',
#    'first_name': 'Campbell',
#    'incumbent': False,
#    'last_name': 'Cavasso',
#    'lead_confidence': 0.0,
#    'party': 'Rep',
#    'value': 20.2},
#   {'choice': 'Other',
#    'first_name': None,
#    'incumbent': False,
#    'last_name': None,
#    'lead_confidence': None,
#    'party': 'N/A',
#    'value': 1.0}],
#  [{'choice': 'Orman',
#    'first_name': 'Greg',
#    'incumbent': False,
#    'last_name': 'Orman',
#    'lead_confidence': 25.9,
#    'party': 'ind',
#    'value': 45.0},
#   {'choice': 'Roberts',
#    'first_name': 'Pat',
#    'incumbent': True,
#    'last_name': 'Roberts',
#    'lead_confidence': 74.1,
#    'party': 'Rep',
#    'value': 46.7},
#   {'choice': 'Other',
#    'first_name': None,
#    'incumbent': False,
#    'last_name': None,
#    'lead_confidence': None,
#    'party': 'N/A',
#    'value': 3.66}],
#  [{'choice': 'Enzi',
#    'first_name': 'Mike',
#    'incumbent': True,
#    'last_name': 'Enzi',
#    'lead_confidence': 100.0,
#    'party': 'Rep',
#    'value': 68.9},
#   {'choice': 'Hardy',
#    'first_name': 'Charlie',
#    'incumbent': False,
#    'last_name': 'Hardy',
#    'lead_confidence': 0.0,
#    'party': 'Dem',
#    'value': 25.5}],
#  [{'choice': 'Alexander',
#    'first_name': 'Lamar',
#    'incumbent': True,
#    'last_name': 'Alexander',
#    'lead_confidence': 100.0,
#    'party': 'Rep',
#    'value': 55.3},
#   {'choice': 'Ball',
#    'first_name': 'Gordon',
#    'incumbent': False,
#    'last_name': 'Ball',
#    'lead_confidence': 0.0,
#    'party': 'Dem',
#    'value': 32.5},
#   {'choice': 'Other',
#    'first_name': None,
#    'incumbent': False,
#    'last_name': None,
#    'lead_confidence': None,
#    'party': 'N/A',
#    'value': 1.16}],
#  [{'choice': 'Risch',
#    'first_name': 'Jim',
#    'incumbent': True,
#    'last_name': 'Risch',
#    'lead_confidence': 100.0,
#    'party': 'Rep',
#    'value': 57.7},
#   {'choice': 'Mitchell',
#    'first_name': 'Nels',
#    'incumbent': False,
#    'last_name': 'Mitchell',
#    'lead_confidence': 0.0,
#    'party': 'Dem',
#    'value': 29.2}],
#  [{'choice': 'Booker',
#    'first_name': 'Cory',
#    'incumbent': True,
#    'last_name': 'Booker',
#    'lead_confidence': 100.0,
#    'party': 'Dem',
#    'value': 52.7},
#   {'choice': 'Bell',
#    'first_name': 'Jeff',
#    'incumbent': False,
#    'last_name': 'Bell',
#    'lead_confidence': 0.0,
#    'party': 'Rep',
#    'value': 37.4},
#   {'choice': 'Other',
#    'first_name': None,
#    'incumbent': False,
#    'last_name': None,
#    'lead_confidence': None,
#    'party': 'N/A',
#    'value': 0.76}],
#  [{'choice': 'Udall',
#    'first_name': 'Tom',
#    'incumbent': True,
#    'last_name': 'Udall',
#    'lead_confidence': 99.9,
#    'party': 'Dem',
#    'value': 52.1},
#   {'choice': 'Weh',
#    'first_name': 'Allen',
#    'incumbent': False,
#    'last_name': 'Weh',
#    'lead_confidence': 0.1,
#    'party': 'Rep',
#    'value': 39.6},
#   {'choice': 'Other',
#    'first_name': None,
#    'incumbent': False,
#    'last_name': None,
#    'lead_confidence': None,
#    'party': 'N/A',
#    'value': 1.0}],
#  [{'choice': 'Inhofe',
#    'first_name': 'Jim',
#    'incumbent': True,
#    'last_name': 'Inhofe',
#    'lead_confidence': 100.0,
#    'party': 'Rep',
#    'value': 64.4},
#   {'choice': 'Silverstein',
#    'first_name': 'Matt',
#    'incumbent': False,
#    'last_name': 'Silverstein',
#    'lead_confidence': 0.0,
#    'party': 'Dem',
#    'value': 27.1},
#   {'choice': 'Other',
#    'first_name': None,
#    'incumbent': False,
#    'last_name': None,
#    'lead_confidence': None,
#    'party': 'N/A',
#    'value': 2.76}],
#  [{'choice': 'Scott',
#    'first_name': 'Tim',
#    'incumbent': True,
#    'last_name': 'Scott',
#    'lead_confidence': 100.0,
#    'party': 'Rep',
#    'value': 55.1},
#   {'choice': 'Dickerson',
#    'first_name': 'Joyce',
#    'incumbent': False,
#    'last_name': 'Dickerson',
#    'lead_confidence': 0.0,
#    'party': 'Dem',
#    'value': 27.5}],
#  [{'choice': 'Graham',
#    'first_name': 'Lindsey',
#    'incumbent': True,
#    'last_name': 'Graham',
#    'lead_confidence': 99.9,
#    'party': 'Rep',
#    'value': 47.6},
#   {'choice': 'Hutto',
#    'first_name': 'Brad',
#    'incumbent': False,
#    'last_name': 'Hutto',
#    'lead_confidence': 0.0,
#    'party': 'Dem',
#    'value': 29.5},
#   {'choice': 'Other',
#    'first_name': None,
#    'incumbent': False,
#    'last_name': None,
#    'lead_confidence': None,
#    'party': 'N/A',
#    'value': 10.0}],
#  [{'choice': 'Cornyn',
#    'first_name': 'John',
#    'incumbent': True,
#    'last_name': 'Cornyn',
#    'lead_confidence': 100.0,
#    'party': 'Rep',
#    'value': 54.0},
#   {'choice': 'Alameel',
#    'first_name': 'David',
#    'incumbent': False,
#    'last_name': 'Alameel',
#    'lead_confidence': 0.0,
#    'party': 'Dem',
#    'value': 30.9},
#   {'choice': 'Other',
#    'first_name': None,
#    'incumbent': False,
#    'last_name': None,
#    'lead_confidence': None,
#    'party': 'N/A',
#    'value': 0.8}],
#  [{'choice': 'Franken',
#    'first_name': 'Al',
#    'incumbent': True,
#    'last_name': 'Franken',
#    'lead_confidence': 100.0,
#    'party': 'Dem',
#    'value': 51.5},
#   {'choice': 'McFadden',
#    'first_name': 'Mike',
#    'incumbent': False,
#    'last_name': 'McFadden',
#    'lead_confidence': 0.0,
#    'party': 'Rep',
#    'value': 39.9},
#   {'choice': 'Other',
#    'first_name': None,
#    'incumbent': False,
#    'last_name': None,
#    'lead_confidence': None,
#    'party': 'N/A',
#    'value': 4.87}],
#  [{'choice': 'Collins',
#    'first_name': 'Susan',
#    'incumbent': True,
#    'last_name': 'Collins',
#    'lead_confidence': 100.0,
#    'party': 'Rep',
#    'value': 61.1},
#   {'choice': 'Bellows',
#    'first_name': 'Shenna',
#    'incumbent': False,
#    'last_name': 'Bellows',
#    'lead_confidence': 0.0,
#    'party': 'Dem',
#    'value': 34.1},
#   {'choice': 'Other',
#    'first_name': None,
#    'incumbent': False,
#    'last_name': None,
#    'lead_confidence': None,
#    'party': 'N/A',
#    'value': 1.5}],
#  [{'choice': 'Rounds',
#    'first_name': 'Mike',
#    'incumbent': False,
#    'last_name': 'Rounds',
#    'lead_confidence': 99.9,
#    'party': 'Rep',
#    'value': 43.4},
#   {'choice': 'Weiland',
#    'first_name': 'Rick',
#    'incumbent': False,
#    'last_name': 'Weiland',
#    'lead_confidence': 0.0,
#    'party': 'Dem',
#    'value': 29.7},
#   {'choice': 'Pressler',
#    'first_name': 'Larry',
#    'incumbent': False,
#    'last_name': 'Pressler',
#    'lead_confidence': None,
#    'party': 'Ind',
#    'value': 17.7},
#   {'choice': 'Other',
#    'first_name': None,
#    'incumbent': False,
#    'last_name': None,
#    'lead_confidence': None,
#    'party': 'N/A',
#    'value': 1.65}],
#  [{'choice': 'Sasse',
#    'first_name': 'Ben',
#    'incumbent': False,
#    'last_name': 'Sasse',
#    'lead_confidence': 100.0,
#    'party': 'Rep',
#    'value': 57.2},
#   {'choice': 'Domina',
#    'first_name': 'David',
#    'incumbent': False,
#    'last_name': 'Domina',
#    'lead_confidence': 0.0,
#    'party': 'Dem',
#    'value': 30.3}],
#  [{'choice': 'Perdue',
#    'first_name': 'David',
#    'incumbent': False,
#    'last_name': 'Perdue',
#    'lead_confidence': 99.9,
#    'party': 'Rep',
#    'value': 47.4},
#   {'choice': 'Nunn',
#    'first_name': 'Michelle',
#    'incumbent': False,
#    'last_name': 'Nunn',
#    'lead_confidence': 0.0,
#    'party': 'Dem',
#    'value': 43.4},
#   {'choice': 'Swafford',
#    'first_name': 'Amanda',
#    'incumbent': False,
#    'last_name': 'Swafford',
#    'lead_confidence': None,
#    'party': 'Lib',
#    'value': 3.7},
#   {'choice': 'Other',
#    'first_name': None,
#    'incumbent': False,
#    'last_name': None,
#    'lead_confidence': None,
#    'party': 'N/A',
#    'value': 1.6}],
#  [{'choice': 'Merkley',
#    'first_name': 'Jeff',
#    'incumbent': True,
#    'last_name': 'Merkley',
#    'lead_confidence': 100.0,
#    'party': 'Dem',
#    'value': 52.7},
#   {'choice': 'Wehby',
#    'first_name': 'Monica',
#    'incumbent': False,
#    'last_name': 'Wehby',
#    'lead_confidence': 0.0,
#    'party': 'Rep',
#    'value': 35.2},
#   {'choice': 'Other',
#    'first_name': None,
#    'incumbent': False,
#    'last_name': None,
#    'lead_confidence': None,
#    'party': 'N/A',
#    'value': 4.54}],
#  [{'choice': 'Cochran',
#    'first_name': 'Thad',
#    'incumbent': True,
#    'last_name': 'Cochran',
#    'lead_confidence': 99.9,
#    'party': 'Rep',
#    'value': 44.2},
#   {'choice': 'Childers',
#    'first_name': 'Travis',
#    'incumbent': False,
#    'last_name': 'Childers',
#    'lead_confidence': 0.0,
#    'party': 'Dem',
#    'value': 26.7},
#   {'choice': 'Other',
#    'first_name': None,
#    'incumbent': False,
#    'last_name': None,
#    'lead_confidence': None,
#    'party': 'N/A',
#    'value': 9.0}],
#  [{'choice': 'Ernst',
#    'first_name': 'Joni',
#    'incumbent': False,
#    'last_name': 'Ernst',
#    'lead_confidence': 94.1,
#    'party': 'Rep',
#    'value': 48.1},
#   {'choice': 'Braley',
#    'first_name': 'Bruce',
#    'incumbent': False,
#    'last_name': 'Braley',
#    'lead_confidence': 5.9,
#    'party': 'Dem',
#    'value': 45.6},
#   {'choice': 'Other',
#    'first_name': None,
#    'incumbent': False,
#    'last_name': None,
#    'lead_confidence': None,
#    'party': 'N/A',
#    'value': 1.76}],
#  [{'choice': 'Sullivan',
#    'first_name': 'Dan',
#    'incumbent': False,
#    'last_name': 'Sullivan',
#    'lead_confidence': 99.8,
#    'party': 'Rep',
#    'value': 50.0},
#   {'choice': 'Begich',
#    'first_name': 'Mark',
#    'incumbent': True,
#    'last_name': 'Begich',
#    'lead_confidence': 0.2,
#    'party': 'Dem',
#    'value': 45.7},
#   {'choice': 'Other',
#    'first_name': None,
#    'incumbent': False,
#    'last_name': None,
#    'lead_confidence': None,
#    'party': 'N/A',
#    'value': 4.98}],
#  [{'choice': 'Durbin',
#    'first_name': 'Dick',
#    'incumbent': True,
#    'last_name': 'Durbin',
#    'lead_confidence': 100.0,
#    'party': 'Dem',
#    'value': 51.6},
#   {'choice': 'Oberweis',
#    'first_name': 'Jim',
#    'incumbent': False,
#    'last_name': 'Oberweis',
#    'lead_confidence': 0.0,
#    'party': 'Rep',
#    'value': 38.7},
#   {'choice': 'Other',
#    'first_name': None,
#    'incumbent': False,
#    'last_name': None,
#    'lead_confidence': None,
#    'party': 'N/A',
#    'value': 3.12}],
#  [{'choice': 'Gardner',
#    'first_name': 'Cory',
#    'incumbent': False,
#    'last_name': 'Gardner',
#    'lead_confidence': 93.2,
#    'party': 'Rep',
#    'value': 49.2},
#   {'choice': 'Udall',
#    'first_name': 'Mark',
#    'incumbent': True,
#    'last_name': 'Udall',
#    'lead_confidence': 6.8,
#    'party': 'Dem',
#    'value': 47.3},
#   {'choice': 'Other',
#    'first_name': None,
#    'incumbent': False,
#    'last_name': None,
#    'lead_confidence': None,
#    'party': 'N/A',
#    'value': '4.892640752232218'},
#   {'choice': 'Undecided',
#    'first_name': None,
#    'incumbent': False,
#    'last_name': None,
#    'lead_confidence': None,
#    'party': 'N/A',
#    'value': 3.5}],
#  [{'choice': 'Warner',
#    'first_name': 'Mark',
#    'incumbent': True,
#    'last_name': 'Warner',
#    'lead_confidence': 99.9,
#    'party': 'Dem',
#    'value': 50.3},
#   {'choice': 'Gillespie',
#    'first_name': 'Ed',
#    'incumbent': False,
#    'last_name': 'Gillespie',
#    'lead_confidence': 0.0,
#    'party': 'Rep',
#    'value': 38.7},
#   {'choice': 'Sarvis',
#    'first_name': 'Robert',
#    'incumbent': False,
#    'last_name': 'Sarvis',
#    'lead_confidence': None,
#    'party': 'Lib',
#    'value': 2.0}],
#  [{'choice': 'Hagan',
#    'first_name': 'Kay',
#    'incumbent': True,
#    'last_name': 'Hagan',
#    'lead_confidence': 69.7,
#    'party': 'Dem',
#    'value': 46.3},
#   {'choice': 'Tillis',
#    'first_name': 'Thom',
#    'incumbent': False,
#    'last_name': 'Tillis',
#    'lead_confidence': 30.3,
#    'party': 'Rep',
#    'value': 45.7},
#   {'choice': 'Haugh',
#    'first_name': 'Sean',
#    'incumbent': False,
#    'last_name': 'Haugh',
#    'lead_confidence': None,
#    'party': 'Lib',
#    'value': 4.9},
#   {'choice': 'Other',
#    'first_name': None,
#    'incumbent': False,
#    'last_name': None,
#    'lead_confidence': None,
#    'party': 'N/A',
#    'value': 1.85}],
#  [{'choice': 'Capito',
#    'first_name': 'Shelley',
#    'incumbent': False,
#    'last_name': 'Moore Capito',
#    'lead_confidence': 100.0,
#    'party': 'Rep',
#    'value': 53.5},
#   {'choice': 'Tennant',
#    'first_name': 'Natalie',
#    'incumbent': False,
#    'last_name': 'Tennant',
#    'lead_confidence': 0.0,
#    'party': 'Dem',
#    'value': 35.8},
#   {'choice': 'Undecided',
#    'first_name': None,
#    'incumbent': False,
#    'last_name': None,
#    'lead_confidence': None,
#    'party': 'N/A',
#    'value': 10.7},
#   {'choice': 'Other',
#    'first_name': None,
#    'incumbent': False,
#    'last_name': None,
#    'lead_confidence': None,
#    'party': 'N/A',
#    'value': '0.27212787062756977'}],
#  [{'choice': 'Shaheen',
#    'first_name': 'Jeanne',
#    'incumbent': True,
#    'last_name': 'Shaheen',
#    'lead_confidence': 89.6,
#    'party': 'Dem',
#    'value': 47.6},
#   {'choice': 'Brown',
#    'first_name': 'Scott',
#    'incumbent': False,
#    'last_name': 'Brown',
#    'lead_confidence': 10.4,
#    'party': 'Rep',
#    'value': 46.2},
#   {'choice': 'Other',
#    'first_name': None,
#    'incumbent': False,
#    'last_name': None,
#    'lead_confidence': None,
#    'party': 'N/A',
#    'value': 1.26}],
#  [{'choice': 'Cassidy',
#    'first_name': 'Bill',
#    'incumbent': False,
#    'last_name': 'Cassidy',
#    'lead_confidence': 100.0,
#    'party': 'Rep',
#    'value': 55.5},
#   {'choice': 'Landrieu',
#    'first_name': 'Mary',
#    'incumbent': True,
#    'last_name': 'Landrieu',
#    'lead_confidence': 0.0,
#    'party': 'Dem',
#    'value': 40.7}],
#  [{'choice': 'Peters',
#    'first_name': 'Gary',
#    'incumbent': False,
#    'last_name': 'Peters',
#    'lead_confidence': 100.0,
#    'party': 'Dem',
#    'value': 51.6},
#   {'choice': 'Land',
#    'first_name': 'Terri Lynn',
#    'incumbent': False,
#    'last_name': 'Land',
#    'lead_confidence': 0.0,
#    'party': 'Rep',
#    'value': 39.8},
#   {'choice': 'Other',
#    'first_name': None,
#    'incumbent': False,
#    'last_name': None,
#    'lead_confidence': None,
#    'party': 'N/A',
#    'value': 3.98}],
#  [{'choice': 'Cotton',
#    'first_name': 'Tom',
#    'incumbent': False,
#    'last_name': 'Cotton',
#    'lead_confidence': 100.0,
#    'party': 'Rep',
#    'value': 51.7},
#   {'choice': 'Pryor',
#    'first_name': 'Mark',
#    'incumbent': True,
#    'last_name': 'Pryor',
#    'lead_confidence': 0.0,
#    'party': 'Dem',
#    'value': 45.6},
#   {'choice': 'Other',
#    'first_name': None,
#    'incumbent': False,
#    'last_name': None,
#    'lead_confidence': None,
#    'party': 'N/A',
#    'value': '3.8016113722650173'},
#   {'choice': 'Undecided',
#    'first_name': None,
#    'incumbent': False,
#    'last_name': None,
#    'lead_confidence': None,
#    'party': 'N/A',
#    'value': 2.7}],
#  [{'choice': 'McConnell',
#    'first_name': 'Mitch',
#    'incumbent': True,
#    'last_name': 'McConnell',
#    'lead_confidence': 100.0,
#    'party': 'Rep',
#    'value': 50.1},
#   {'choice': 'Grimes',
#    'first_name': 'Alison Lundergan',
#    'incumbent': False,
#    'last_name': 'Grimes',
#    'lead_confidence': 0.0,
#    'party': 'Dem',
#    'value': 44.1},
#   {'choice': 'Other',
#    'first_name': None,
#    'incumbent': False,
#    'last_name': None,
#    'lead_confidence': None,
#    'party': 'N/A',
#    'value': 2.9}]]

# %%
rows = []
for race in cands:
    race_row = []
    for choice in race:
        if choice['party'] == 'Rep':
            race_row.append(str(choice['choice']))
    for choice in race:
        if (choice['party'] == 'Dem') or (choice['party'] == 'ind'):
            race_row.append(str(choice['choice']))
    for choice in race:
        if choice['incumbent'] == True:
            race_row.append(str(choice['party']))
    if len(race_row) <= 2:
        race_row.append(np.nan)
    rows.append(race_row)

missing = ['Zaccaria', 'Reed', 'Dem']
rows[2] = missing
rows
# Out:
# [['Wade', 'Coons', 'Dem'],
#  ['Herr', 'Markey', 'Dem'],
#  ['Zaccaria', 'Reed', 'Dem'],
#  ['Daines', 'Curtis', nan],
#  ['Lankford', 'Johnson', nan],
#  ['Cavasso', 'Schatz', 'Dem'],
#  ['Roberts', 'Orman', 'Rep'],
#  ['Enzi', 'Hardy', 'Rep'],
#  ['Alexander', 'Ball', 'Rep'],
#  ['Risch', 'Mitchell', 'Rep'],
#  ['Bell', 'Booker', 'Dem'],
#  ['Weh', 'Udall', 'Dem'],
#  ['Inhofe', 'Silverstein', 'Rep'],
#  ['Scott', 'Dickerson', 'Rep'],
#  ['Graham', 'Hutto', 'Rep'],
#  ['Cornyn', 'Alameel', 'Rep'],
#  ['McFadden', 'Franken', 'Dem'],
#  ['Collins', 'Bellows', 'Rep'],
#  ['Rounds', 'Weiland', nan],
#  ['Sasse', 'Domina', nan],
#  ['Perdue', 'Nunn', nan],
#  ['Wehby', 'Merkley', 'Dem'],
#  ['Cochran', 'Childers', 'Rep'],
#  ['Ernst', 'Braley', nan],
#  ['Sullivan', 'Begich', 'Dem'],
#  ['Oberweis', 'Durbin', 'Dem'],
#  ['Gardner', 'Udall', 'Dem'],
#  ['Gillespie', 'Warner', 'Dem'],
#  ['Tillis', 'Hagan', 'Dem'],
#  ['Capito', 'Tennant', nan],
#  ['Brown', 'Shaheen', 'Dem'],
#  ['Cassidy', 'Landrieu', 'Dem'],
#  ['Land', 'Peters', nan],
#  ['Cotton', 'Pryor', 'Dem'],
#  ['McConnell', 'Grimes', 'Rep']]

# %%
df2 = pd.DataFrame(rows)
print(df.shape)
print(df2.shape)
# Out:
# (35, 1)
# (35, 3)

# %%
candidates = pd.concat([df, df2], axis = 1)
candidates.columns = ['State', 'R', 'D or I', 'Incumbent']
candidates.head(10)
# Out:
#   State          R    D or I Incumbent
# 0    DE       Wade     Coons       Dem
# 1    MA       Herr    Markey       Dem
# 2    RI   Zaccaria      Reed       Dem
# 3    MT     Daines    Curtis       NaN
# 4    OK   Lankford   Johnson       NaN
# 5    HI    Cavasso    Schatz       Dem
# 6    KS    Roberts     Orman       Rep
# 7    WY       Enzi     Hardy       Rep
# 8    TN  Alexander      Ball       Rep
# 9    ID      Risch  Mitchell       Rep

# %% [markdown]
# ## Problem 2: Confidence Intervals
#
# Compute a 99% confidence interval for each state.

# %% [markdown]
# #### Problem 2(a)
#
# Assume you have $M$ polls with sample sizes $n_1, \dots, n_M$. If the polls are independent, what is the average of the variances of each poll if the true proportion is $p$?

# %% [markdown]
# ** Your answer here: **

# %% [markdown]
# #### Problem 2(b)
#
# Compute the square root of these values in Problem 2(a) for the republican candidates in each race. Then, compute the standard deviations of the observed poll results for each race.

# %%
def sds(editinfo, polls):
    obs_sds = []
    ther_sds = []
    npolls = []
    for i, election in enumerate(editinfo):
        election_polls = polls[election['slug']]
        
        npoll = election_polls.shape[0]
        
        n = election_polls['Number of Observations']
        p = election_polls[candidates['R'].ix[i]]/100
        
        p_mean = np.mean(p)
        ther_sd = np.sqrt(p_mean*(1-p_mean)*np.mean(1./n))
        
        obs_sd = np.std(p)
        
        obs_sds.append(obs_sd)
        ther_sds.append(ther_sd)
        npolls.append(npoll)
    return obs_sds, ther_sds, npolls
        
    #print(npolls)
obs_sds, ther_sds, npolls = sds(editinfo, polls)

# %% [markdown]
# #### Problem 2(c)
#
# Plot observed versus theoretical (average of the theoretical SDs) with the area of the point proportional to number of polls. How do these compare?

# %%
plt.scatter(ther_sds, obs_sds,  s=npolls)
plt.xlabel('Theoretical Standard Deviation')
plt.ylabel('Observed Standard Deviation')
plt.title('Observed vs Theoretical Deviation, Dot Area = Npolls')
plt.show()

# %% [markdown]
# ** Your answer here: **

# %% [markdown]
# #### Problem 2(d)
#
# Repeat Problem 2(c) but include only the most recent polls from the last two months. Do they match better or worse or the same? Can we just trust the theoretical values?

# %%
dup_polls = polls
for key in dup_polls:
    #df = dup_polls[key]
    dup_polls[key] = dup_polls[key][dup_polls[key]['Start Date'] > '2014-09-04']

# %%
robs_sds, rther_sds, rnpolls = sds(editinfo, dup_polls)

# %%
gdf = pd.DataFrame()
gdf['x'] = rther_sds
gdf['y'] = robs_sds
gdf['z'] = rnpolls
cmap = sns.cubehelix_palette(8, start=.5, rot=-.75)
sns.lmplot('x', 'y', data=gdf, fit_reg=False, scatter_kws={"s": (100*rnpolls)})
plt.xlabel('Theoretical Standard Deviation')
plt.ylabel('Observed Standard Deviation')
plt.title('Observed vs Theoretical Deviation, Dot Area = Npolls')

plt.show()

# %% [markdown]
# ** Your answer here: **

# %% [markdown]
# #### Problem 2(e)
#
# Create a scatter plot with each point representing one state. Is there one or more races that are outlier in that it they have much larger variabilities than expected ? Explore the original poll data and explain why the discrepancy?

# %%
sns.lmplot('x', 'y', data=gdf, fit_reg=False)
plt.xlabel('Theoretical Standard Deviation')
plt.ylabel('Observed Standard Deviation')
plt.title('Observed vs Theoretical Deviation, Dot Area = Npolls')
for i in range(len(rnpolls)):
    plt.text(rther_sds[i], robs_sds[i], candidates.ix[i,'State'], fontsize=8)
axes = plt.gca()
axes.set_xlim([0,0.07])
axes.set_ylim([0,0.07])
plt.show()

# %% [markdown]
# ** Your answer here: **
# Idaho is a major outlier, as is Hawaii and Maine.

# %% [markdown]
# #### Problem 2(f)
#
# Construct confidence intervals for the difference in each race. Use either theoretical or data driven estimates of the standard error depending on your answer to this question. Use the results in Problem 2(e), to justify your choice.

# %%
from scipy import stats
def poll_diff(editinfo, polls):
    rows = []
    for i, election in enumerate(editinfo):
        polls_key = election['slug']
        this_election = polls[polls_key]
        
        npolls = this_election.shape[0]
        
        diff = (this_election[candidates['R'].ix[i]] - this_election[candidates['D or I'].ix[i]])/100
        mean_diff = np.mean(diff)
        
        se = np.std(diff)/np.sqrt(npolls)
        sd = np.std(diff)
        
        for c in election['estimates']:
            if c['party'] == 'Rep' :
                r1 = c['value']
        
        for c in election['estimates']:
            if c['party'] == 'Dem' or c['party'] == 'ind' :
                r2 = c['value']
        
        result = (r1-r2)/100
        margin = stats.t.ppf(1-0.005, npolls)
        
        rows.append((polls_key, mean_diff, se, sd, margin))
    return rows

estimates = pd.DataFrame(poll_diff(editinfo, dup_polls), columns = ['race', 'mean', 'se', 'sd', 'margin'])
estimates.sort_values('mean', inplace = True)
estimates.head()
# Out:
#                                          race      mean        se        sd  \
# 4        2014-hawaii-senate-cavasso-vs-schatz -0.420000  0.044284  0.108474
# 2   2014-rhode-island-senate-zaccaria-vs-reed -0.406667  0.024191  0.041899
# 1    2014-massachusetts-senate-herr-vs-markey -0.220833  0.011393  0.039467
# 0          2014-delaware-senate-wade-vs-coons -0.185000  0.019526  0.039051
# 19        2014-oregon-senate-wehby-vs-merkley -0.162857  0.018263  0.048319
#
#       margin
# 4   3.707428
# 2   5.840909
# 1   3.054540
# 0   4.604095
# 19  3.499483

# %%
sns.boxplot(x='race', y = 'mean', data = estimates)
plt.xticks(range(estimates.shape[0]), estimates['race'].values, rotation=90)
plt.errorbar(range(estimates.shape[0]), estimates['mean'], yerr = estimates['se']*estimates['margin'], fmt='+')
plt.xlabel('Race')
plt.ylabel('Fractional Difference in Polling (R-D)')
plt.title('2014 Senate Election Polling Differences (99% Confidence Intervals)')
plt.show()

# %% [markdown]
# # Problem 3: Prediction and Posterior Probabilities
#
# Perform a Bayesian analysis to predict the probability of Republicans winning in each state then provide a posterior distribution of the number of republicans in the senate.

# %% [markdown]
# #### Problem 3(a)
#
# First, we define a Bayesian model for each race. The prior for the difference $\theta$ between republicans and democtrats will be $N(\mu,\tau^2)$. Say before seeing poll data you have no idea who is going to win, what should $\mu$ be? How about $\tau$, should it be large or small?

# %% [markdown]
# ** Your answer here: **
# Since we have no informed idea who will win, the prior mean ($\mu$) = 0, and based on the fact that most elections are fairly close, $\tau$ should be small.

# %% [markdown]
# #### Problem 3(b)
#
# What is the distribution of $d$ conditioned on $\theta$. What is the posterior distribution of $\theta | d$?
#
# **Hint**: Use normal approximation.

# %% [markdown]
# **Your answer here:**
# $d|θ = N(θ, \sigma^2/M)$ where $\sigma^2$ is observed sample variance and M is the number of polls used to calculate $d$.
# in that case, then:
# $θ|d$ ~ $N(B\mu+(1−B)d,(1−B)\sigma^2/M)$ , where $B=\frac{1/\tau^2}{M/\sigma^2+1/\tau^2B}$

# %% [markdown]
# #### Problem 3(c)
#
# The prior represents what we think before hand. We do not know who is expected to win, so we assume $\mu=0$. For this problem estimate $\tau$ using the observed differences across states (Hint: $\tau$ represents the standard deviation of a typical difference). Compute the posterior mean for each state and plot it against original average. Is there much change? Why or why not?

# %%
###check our data is roughly normal distributed###
plt.hist(estimates['mean'])
plt.show()

# %%
tau = np.std(estimates['mean'])
B = (1/tau**2)/(1/estimates['se']**2+1/tau**2)
estimates['mu_post'] = (1-B)*estimates['mean']

sns.lmplot('mean', 'mu_post', data = estimates, fit_reg = False, scatter_kws={ 
                        "s": 20})
plt.plot((-1,1),(-1,1), c='black', linewidth=1)
plt.show()

# %% [markdown]
# **Your answer here:**
# Not much change, probably because the posterior is being informed primarily by the data, rather than the prior.

# %% [markdown]
# #### Problem 3(d)
#
# For each state, report a probabilty of Republicans winning. How does your answer here compare to the other aggregators?

# %%
### Your code here ###
estimates['sd_post'] = np.sqrt((1-B)*estimates['se']**2)

estimates['R_win_prob'] = 1-scipy.stats.norm.cdf(0, loc=estimates['mu_post'], scale=estimates['sd_post'])
estimates.sort_values('R_win_prob', inplace = True)
sns.boxplot('race', 'R_win_prob', data=estimates)
plt.xticks(range(estimates.shape[0]), estimates['race'].values, rotation=90)
plt.ylabel('Probability of Republican Win')
plt.xlabel('Race')
plt.show()

# %% [markdown]
# **Your answer here:**
# Not very favorably, it appears we need more uncertainty incorporated into our model, as many of the states have a very black/white answer.

# %% [markdown]
# #### Problem 3(e)
#
# Use the posterior distributions in a Monte Carlo simulation to generate election results. In each simulation compute the total number of seats the Republican control. Show a histogram of these results.

# %%
num_states = estimates.shape[0]

NSIM = 10000
simarr = np.zeros(NSIM, dtype=int)
for i in range(NSIM):
    simulated = 30 + np.sum(np.random.normal(estimates['mu_post'], scale=estimates['sd_post'], size =num_states) > 0 )
    simarr[i] = int(simulated)
plt.hist(simarr, bins=range(min(simarr)-1, max(simarr)+3))
plt.show()

# %% [markdown]
# ## Problem 4
#
# Predict the results for the 2014 Midterm Elections. We will have a three competitions with the terms for scoring entries described above. For both questions below, **explain** or provide commentary on how you arrived at your predictions including code.
#
# **Hint**: Use election results from 2010, 2012 to build and test models.

# %% [markdown]
# #### Problem 4(a)
#
# Predict the number of Republican senators. You may provide an interval. Smallest interval that includes the election day result wins.
#
# **Note**: we want the total so add the numbers of those that are not up for election.

# %%
url2012 = 'http://elections.huffingtonpost.com/pollster/api/charts/?topic=2012-senate'
info2012 = requests.get(url2012).json()

# %% [markdown]
# **Provide an explanation of methodology here**:

# %%
### to be consistent, we eliminate additional special elections ###
states2012 = [str(ele['state']) for ele in info2012]
titles2012 = [str(ele['title']) for ele in info2012]
countstates2012 = Counter(states2012)
duplicate2012 = [k for (k,v) in countstates2012.items() if v > 1]
for dups in duplicate2012:
    ind = [i for i,x in enumerate(states2012) if x == dups ]
    for ele in ind:
        print(titles2012[ele], ele)
# Out:
# 2012 Florida Senate Republican Primary 6
# 2012 Florida Senate: Mack vs. Nelson 26

# %%
idx = [6]
editinfo2012 = [i for (j,i) in enumerate(info2012) if j not in idx]
print(len(info2012))
print(len(editinfo2012))
# Out:
# 30
# 29

# %%
cands2012 = [ele['estimates'] for ele in editinfo2012]
rows2012 = []
for race in cands2012:
    race_row = []
    for choice in race:
        if choice['party'] == 'Rep':
            race_row.append(str(choice['choice']))
    for choice in race:
        if (choice['party'] == 'Dem') or (choice['party'] == 'ind'):
            race_row.append(str(choice['choice']))
    #for choice in race:
    #    if choice['incumbent'] == True:
    #        race_row.append(str(choice['party']))
    #if len(race_row) <= 2:
    #    race_row.append(np.nan)
    rows2012.append(race_row)
rows2012[0] = ['Hatch', 'Howell']
rows2012[1] = ['Corker', 'Clayton']
rows2012[2] = ['Bongino', 'Cardin']
rows2012[6] = ['Mack', 'Weldon']
rows2012
# Out:
# [['Hatch', 'Howell'],
#  ['Corker', 'Clayton'],
#  ['Bongino', 'Cardin'],
#  ['Bills', 'Klobuchar'],
#  ['Emken', 'Feinstein'],
#  ['Fischer', 'Kerrey'],
#  ['Mack', 'Weldon'],
#  ['Smith', 'Casey'],
#  ['Cruz', 'Sadler'],
#  ['Long', 'Gillibrand'],
#  ['Wilson', 'Heinrich'],
#  ['Akin', 'McCaskill'],
#  ['Mourdock', 'Donnelly'],
#  ['Lingle', 'Hirono'],
#  ['McMahon', 'Murphy'],
#  ['Raese', 'Manchin'],
#  ['Hinckley', 'Whitehouse'],
#  ['Summers', 'Dill'],
#  ['Thompson', 'Baldwin'],
#  ['Baumgartner', 'Cantwell'],
#  ['Allen', 'Kaine'],
#  ['Kyrillos', 'Menendez'],
#  ['Heller', 'Berkley'],
#  ['Rehberg', 'Tester'],
#  ['Hoekstra', 'Stabenow'],
#  ['Mack', 'Nelson'],
#  ['Flake', 'Carmona'],
#  ['Mandel', 'Brown'],
#  ['Brown', 'Warren']]

# %%
cands_2012_df = pd.DataFrame([ele['state'] for ele in editinfo2012])
cands_2012_df.head()
# Out:
#     0
# 0  UT
# 1  TN
# 2  MD
# 3  MN
# 4  CA

# %%
cands_2012_df = pd.DataFrame([ele['state'] for ele in editinfo2012])
cancan_2012 = pd.DataFrame(rows2012)
candidates2012 = pd.concat([cands_2012_df, cancan_2012], axis = 1)
candidates2012.columns = ['State', 'R', 'D or I']
candidates2012.head()
# Out:
#   State        R     D or I
# 0    UT    Hatch     Howell
# 1    TN   Corker    Clayton
# 2    MD  Bongino     Cardin
# 3    MN    Bills  Klobuchar
# 4    CA    Emken  Feinstein

# %%
path2012 = 'C:/Users/Wolfgang Rahfeldt/Desktop/results2012B.csv'
def true_results(filepath):
    results2012 = pd.read_csv(filepath, thousands=',')
    c_lst = ['Democr.', 'Republ.', 'Other']
    for c in c_lst:
        results2012[c] = results2012[c].str[1:]
        results2012[c] = results2012[c].replace('%','',regex=True).astype('float')/100
    results2012['rd_diff'] = (results2012['Republ.'] -results2012['Democr.'])/(results2012['Democr.'] + results2012['Republ.'] + results2012['Other'])
    results2012['State'] = results2012['State'].str.lower()
    fresults2012 = results2012[['State','rd_diff']]
    return fresults2012
tresults2012 = true_results(path2012)
tresults2012.head()
# Out:
#          State  rd_diff
# 0      arizona   0.0302
# 1   california  -0.2504
# 2  connecticut  -0.1175
# 3     delaware  -0.3747
# 4      florida  -0.1300

# %%
path2014 = 'C:/Users/Wolfgang Rahfeldt/Desktop/results2014.csv'
tresults2014 = true_results(path2014)
tresults2014.head()
# Out:
#       State   rd_diff
# 0   alabama  0.972500
# 1    alaska  0.021300
# 2  arkansas  0.170700
# 3  colorado  0.019402
# 4  delaware -0.135986

# %%
polls2012 = dict((election['slug'], build_frame(election['url']+'.csv')) for election in editinfo2012)
polls2012
# Out:
# C:\Users\Wolf\Anaconda3\lib\site-packages\ipykernel\__main__.py:12: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
# {'2012-arizona-senate-flake-vs-carmona':                                  Pollster Start Date   End Date  \
#  0                                 PPP (D) 2012-11-02 2012-11-03
#  1                                  YouGov 2012-10-31 2012-11-03
#  2                               Rasmussen 2012-10-21 2012-10-21
#  3              Anzalone-Liszt (D-Carmona) 2012-10-17 2012-10-21
#  4                                  YouGov 2012-10-04 2012-10-11
#  5                Behavior Research Center 2012-10-04 2012-10-10
#  6                  GS Strategies (R-NRSC) 2012-10-08 2012-10-09
#  7                      Tarrance (R-Flake) 2012-10-07 2012-10-09
#  8                        Harstad (D-DSCC) 2012-10-07 2012-10-09
#  9                                 PPP (D) 2012-10-01 2012-10-03
#  10       Moore Information (R-HighGround) 2012-09-25 2012-09-26
#  11                              Rasmussen 2012-09-25 2012-09-25
#  12             Anzalone-Liszt (D-Carmona) 2012-09-18 2012-09-23
#  3        Live Phone     41.0    47.0       11.0    NaN
#  4        Live Phone     43.0    49.0        7.0    1.0
#  5        Live Phone     40.0    46.0       12.0    NaN
#  6   Automated Phone     47.0    48.0        3.0    2.0
#  7        IVR/Online     43.0    47.0        6.0    4.0
#  8        Live Phone     44.0    44.0        NaN    NaN
#  9   Automated Phone     44.0    48.0        8.0    NaN
#  10       Live Phone     38.0    44.0       17.0    NaN
#  11       Live Phone     44.0    46.0        8.0    NaN
#  12         Internet     40.0    42.0       18.0    NaN
#  13  Automated Phone     46.0    51.0        1.0    2.0
#  14       Live Phone     42.0    39.0       14.0    NaN
#  15       Live Phone     48.0    47.0        4.0    NaN
#  16  Automated Phone     42.0    48.0       10.0    NaN
#  17       Live Phone     33.0    37.0       28.0    1.0
#  18         Internet     45.0    41.0       14.0    NaN
#  19       Live Phone     49.0    46.0        4.0    NaN
#  20  Automated Phone     44.0    48.0        8.0    NaN
#  21  Automated Phone     49.0    46.0        5.0    1.0
#  22  Automated Phone     42.0    50.0        8.0    NaN
#  23       Live Phone     43.0    46.0        9.0    NaN
#  24       Live Phone     37.0    52.0        9.0    0.0
#  25  Automated Phone     43.0    50.0        6.0    NaN
#  26       Live Phone     38.0    49.0       11.0    2.0
#  27  Automated Phone     38.0    54.0        9.0    NaN
#
#                                           Pollster URL  \
#  0   http://elections.huffingtonpost.com/pollster/p...
#  1   http://elections.huffingtonpost.com/pollster/p...
#  2   http://elections.huffingtonpost.com/pollster/p...
#  3   http://elections.huffingtonpost.com/pollster/p...
#  4   http://elections.huffingtonpost.com/pollster/p...
#  5   http://elections.huffingtonpost.com/pollster/p...
#  6   http://elections.huffingtonpost.com/pollster/p...
#  7   http://elections.huffingtonpost.com/pollster/p...
#  8   http://elections.huffingtonpost.com/pollster/p...
#  9   http://elections.huffingtonpost.com/pollster/p...
#  10  http://elections.huffingtonpost.com/pollster/p...
#  11  http://elections.huffingtonpost.com/pollster/p...
#  12  http://elections.huffingtonpost.com/pollster/p...
#  13  http://elections.huffingtonpost.com/pollster/p...
#  14  http://elections.huffingtonpost.com/pollster/p...
#  15  http://elections.huffingtonpost.com/pollster/p...
#  16  http://elections.huffingtonpost.com/pollster/p...
#  17  http://elections.huffingtonpost.com/pollster/p...
#  18  http://elections.huffingtonpost.com/pollster/p...
#  19  http://elections.huffingtonpost.com/pollster/p...
#  20  http://elections.huffingtonpost.com/pollster/p...
#  21  http://elections.huffingtonpost.com/pollster/p...
#  22  http://elections.huffingtonpost.com/pollster/p...
#  23  http://elections.huffingtonpost.com/pollster/p...
#  24  http://elections.huffingtonpost.com/pollster/p...
#  25  http://elections.huffingtonpost.com/pollster/p...
#  26  http://elections.huffingtonpost.com/pollster/p...
#  27  http://elections.huffingtonpost.com/pollster/p...
#
#                                             Source URL     Partisan  \
#  0   http://today.yougov.com/news/2012/11/04/connec...  Nonpartisan
#  1   http://www.publicpolicypolling.com/pdf/2011/PP...     Pollster
#  2   http://www.rasmussenreports.com/public_content...  Nonpartisan
#  3   http://www.scribd.com/doc/111151198/CT-Sen-Got...      Sponsor
#  4   http://www.quinnipiac.edu/institutes-centers/p...  Nonpartisan
#  5   http://hotlineoncall.nationaljournal.com/archi...     Pollster
#  6   http://www.rasmussenreports.com/public_content...  Nonpartisan
#  7   http://www.surveyusa.com/client/PollReport.asp...  Nonpartisan
#  8   http://www.realclearpolitics.com/articles/2012...  Nonpartisan
#  9   http://www.scribd.com/doc/110452957/CT-Sen-PPP...      Sponsor
#  10  http://www.courant.com/news/politics/hc-uconn-...  Nonpartisan
#  11  http://www.siena.edu/uploadedfiles/home/parent...  Nonpartisan
#  12  http://today.yougov.com/news/2012/10/16/connec...  Nonpartisan
#  13  http://www.rasmussenreports.com/public_content...  Nonpartisan
#  14  http://www.politico.com/blogs/burns-haberman/2...     Pollster
#  15  http://www.quinnipiac.edu/institutes-and-cente...  Nonpartisan
#  16  http://www.publicpolicypolling.com/pdf/2011/PP...     Pollster
#  17  http://today.uconn.edu/blog/2012/09/university...  Nonpartisan
#  18  http://cdn.yougov.com/cumulus_uploads/document...  Nonpartisan
#  19  http://www.quinnipiac.edu/institutes-and-cente...  Nonpartisan
#  20  http://www.publicpolicypolling.com/pdf/2011/PP...      Sponsor
#  21  http://www.rasmussenreports.com/public_content...  Nonpartisan
#  22  http://www.publicpolicypolling.com/pdf/2011/PP...     Pollster
#  23  http://www.quinnipiac.edu/institutes-and-cente...  Nonpartisan
#  24  http://www.quinnipiac.edu/institutes-and-cente...  Nonpartisan
#  25  http://www.publicpolicypolling.com/pdf/2011/PP...     Pollster
#  26  http://www.quinnipiac.edu/institutes-and-cente...  Nonpartisan
#  27  http://www.dailykos.com/polling/2011/3/17/CT-D...      Sponsor
#
#     Affiliation  Question Text  Question Iteration
#  0         None            NaN                   1
#  1          Dem            NaN                   1
#  2         None            NaN                   1
#  3          Dem            NaN                   1
#  4         None            NaN                   1
#  5          Dem            NaN                   1
#  6         None            NaN                   1
#  7         None            NaN                   1
#  8         None            NaN                   1
#  
#  45  2012-06-20 14:48:39                     594      Likely Voters
#  46  2012-06-14 10:09:54                     500      Likely Voters
#  47  2012-05-15 16:42:15                     851  Registered Voters
#  48  2012-05-11 12:00:54                     500      Likely Voters
#  49  2012-04-16 14:48:34                    1136      Likely Voters
#  50  2012-03-28 17:31:12                     750      Likely Voters
#  51  2012-02-28 15:37:10                     500      Likely Voters
#  52  2012-03-30 15:07:23                     900  Registered Voters
#  53  2012-02-22 13:06:38                     716  Registered Voters
#  54  2012-02-13 15:11:52                     500      Likely Voters
#  55  2012-02-13 15:12:21                    1170      Likely Voters
#  56  2012-02-13 15:12:38                     830      Likely Voters
#  57  2012-02-13 15:12:52                    1636      Likely Voters
#
#                 Mode  Baldwin  Thompson  Undecided  Other  \
#  0   Automated Phone     51.0      48.0        2.0    NaN
#  1          Internet     50.0      48.0        NaN    2.0
#  2          Internet     48.0      47.0        5.0    NaN
#  3   Automated Phone     49.0      46.0        NaN    5.0
#  4        Live Phone     45.0      47.0        NaN    NaN
#  5   Automated Phone     47.0      48.0        4.0    2.0
#  6        Live Phone     48.0      45.0        7.0    NaN
#  7   Automated Phone     48.0      48.0        2.0    1.0
#  8        Live Phone     48.0      47.0        1.0    4.0
#  9        Live Phone     43.0      46.0       11.0    NaN
#  10       Live Phone     47.0      43.0        6.0    NaN
#  11  Automated Phone     47.0      48.0        4.0    2.0
#  12       Live Phone     49.0      44.0        7.0    NaN
#  13         Internet     50.0      47.0        NaN    3.0
#  14  Automated Phone     46.0      48.0        3.0    3.0
#  15       Live Phone     47.0      45.0        NaN    NaN
#  16       Live Phone     49.0      45.0        5.0    1.0
#  17       Live Phone     48.0      44.0        8.0    NaN
#  18  Automated Phone     47.0      46.0        2.0    4.0
#  19       Live Phone     45.0      46.0        7.0    NaN
#  20         Internet     48.0      43.0        9.0    NaN
#  21  Automated Phone     51.0      47.0        2.0    1.0
#  22       Live Phone     48.0      46.0        5.0    NaN
#  23  Automated Phone     47.0      45.0        6.0    1.0
#  24  Automated Phone     49.0      46.0        6.0    NaN
#  25       Live Phone     48.0      45.0        NaN    NaN
#  26       Live Phone     48.0      44.0        6.0    NaN
#  27  Automated Phone     52.0      40.0        8.0    NaN
#  28  Automated Phone     49.0      45.0        6.0    NaN
#  29       Live Phone     48.0      46.0        5.0    NaN
#  30  Automated Phone     49.0      46.0        4.0    2.0
#  31       Live Phone     47.0      47.0        6.0    NaN
#  32       Live Phone     50.0      41.0        6.0    NaN
#  33         Internet     43.0      47.0        9.0    NaN
#  34  Automated Phone     48.0      45.0        6.0    NaN
#  35       Live Phone     50.0      45.0        5.0    NaN
#  36       Live Phone     44.0      50.0        4.0    1.0
#  37  Automated Phone     44.0      49.0        7.0    NaN
#  38       Live Phone     41.0      50.0        8.0    NaN
#  39  Automated Phone     43.0      54.0        3.0    1.0
#  40       Live Phone     47.0      47.0        5.0    1.0
#  41       Live Phone     43.0      48.0        NaN    NaN
#  42  Automated Phone     48.0      41.0        6.0    5.0
#  43       Live Phone     41.0      45.0        NaN    NaN
#  44  Automated Phone     45.0      45.0       11.0    NaN
http://www.rasmussenreports.com/public_content...  Nonpartisan
#  47  http://www.dailykos.com/polling/2012/5/11/WI/1...      Sponsor
#  48  http://www.rasmussenreports.com/public_content...  Nonpartisan
#  49  http://www.dailykos.com/polling/2012/4/13/WI/1...      Sponsor
#  50  http://www.rasmussenreports.com/public_content...  Nonpartisan
#  51  http://www.rasmussenreports.com/public_content...  Nonpartisan
#  52  http://www.publicpolicypolling.com/pdf/2011/PP...     Pollster
#  53  https://law.marquette.edu/poll/wp-content/uplo...  Nonpartisan
#  54  http://www.rasmussenreports.com/public_content...  Nonpartisan
#  55  http://www.publicpolicypolling.com/pdf/2011/PP...      Sponsor
#  56  http://www.publicpolicypolling.com/pdf/PPP_Rel...      Sponsor
#  57  http://www.publicpolicypolling.com/pdf/PPP_Rel...      Sponsor
#
#     Affiliation  Question Text  Question Iteration
#  0          Dem            NaN                   1
#  1         None            NaN                   1
#  2         None            NaN                   1
#  3         None            NaN                   1
#  4          Rep            NaN                   1
#  5          Rep            NaN                   1
#  6          Dem            NaN                   1
#  7         None            NaN                   1
#  8         None            NaN                   1
#  9         None            NaN                   1
#  10        None            NaN                   1
#  11        None            NaN                   1
#  12         Dem            NaN                   1
#  13        None            NaN                   1
#  14        None            NaN                   1
#  15        None            NaN                   1
#  16        None            NaN                   1
#  17         Dem            NaN                   1
#  18         Rep            NaN                   1
#  19        None            NaN                   1
#  20        None            NaN                   1
#  21        None            NaN                   1
#  22        None            NaN                   1
#  23         Rep            NaN                   1
#  24         Dem            NaN                   1
#  25         Rep            NaN                   1
#  26        None            NaN                   1
#  27        None            NaN                   1
#  28         Dem            NaN                   1
#  29        None            NaN                   1
#  30        None            NaN                   1
#  31        None            NaN                   1
#  32        None            NaN                   1
#  33        None            NaN                   1
#  34         Dem            NaN                   1
#  35         Dem            NaN                   1
#  36        None            NaN                   1
#  37         Dem            NaN                   1
#  38        None            NaN                   1
#  39        None            NaN                   1
#  40        None            NaN                   1
#  41        None            NaN                   1
#  42        None            NaN                   1
#  43        None            NaN                   1
#  44         Dem            NaN                   1
#  45        None            NaN                   1
#  46        None            NaN                   1
#  47         Dem            NaN                   1
#  48        None            NaN                   1
#  49         Dem            NaN                   1
#  50        None            NaN                   1
#  51        None            NaN                   1
#  52         Dem            NaN                   1
#  53        None            NaN                   1
#  54        None            NaN                   1
#  55         Dem            NaN                   1
#  56         Dem            NaN                   1
#  57         Dem            NaN                   1  }

# %%
def results_polls_diff(editinfo, polls, can):
    rows = []
    for i, election in enumerate(editinfo):
        polls_key = election['slug']
        this_election = polls[polls_key]
        
        npolls = this_election.shape[0]
        
        diff = (this_election[can['R'].ix[i]] - this_election[can['D or I'].ix[i]])/100
        
        #if election['estimates'] != []:
        #    for c in election['estimates']:
        #        if c['party'] == 'Rep' :
        #            r1 = c['value']
        #    for c in election['estimates']:
        #        if c['party'] == 'Dem' or c['party'] == 'ind' :
        #            r2 = c['value']
        #    result = (float(r1)-float(r2))/100
        #else:
        #    result = 'NaN'
        
        rows.append((polls_key, [d for d in diff]))
    return rows
result_df = pd.DataFrame(results_polls_diff(editinfo, polls, candidates), columns = ['race', 'poll_diff'])
ana_2014_df = result_df.set_index(['race']).poll_diff.apply(pd.Series).stack().reset_index(['race'], name='poll_diff')
start = '2014-'
end = '-senate'
extract_state = lambda x: re.search('%s(.*)%s' % (start, end), x).group(1)
ana_2014_df['State'] = ana_2014_df['race'].apply(extract_state)
ana_2014_df.head()
# Out:
#                                        race  poll_diff          State
# 0        2014-delaware-senate-wade-vs-coons      -0.18       delaware
# 1        2014-delaware-senate-wade-vs-coons      -0.16       delaware
# 2        2014-delaware-senate-wade-vs-coons      -0.25       delaware
# 3        2014-delaware-senate-wade-vs-coons      -0.15       delaware
# 0  2014-massachusetts-senate-herr-vs-markey      -0.20  massachusetts

# %%
result_df_2012 = pd.DataFrame(results_polls_diff(editinfo2012, polls2012, candidates2012), columns = ['race', 'poll_diff'])
ana_2012_df = result_df_2012.set_index(['race']).poll_diff.apply(pd.Series).stack().reset_index(['race'], name='poll_diff')
start = '2012-'
end = '-senate'
extract_state = lambda x: re.search('%s(.*)%s' % (start, end), x).group(1)
ana_2012_df['State'] = ana_2012_df['race'].apply(extract_state)
ana_2012_df.head()
# Out:
#                                       race  poll_diff      State
# 0         2012-utah-senate-hatch-vs-howell       0.37       utah
# 1         2012-utah-senate-hatch-vs-howell       0.39       utah
# 0  2012-tennessee-senate-corker-vs-clayton       0.33  tennessee
# 1  2012-tennessee-senate-corker-vs-clayton       0.38  tennessee
# 2  2012-tennessee-senate-corker-vs-clayton       0.21  tennessee

# %%
fana_2012_df = pd.merge(ana_2012_df, tresults2012, on = 'State', how = 'inner')
fana_2014_df = pd.merge(ana_2014_df, tresults2014, on = 'State', how = 'inner')
final_df = pd.concat([fana_2012_df, fana_2014_df])
final_df.head()
# Out:
#                                       race  poll_diff      State  rd_diff
# 0         2012-utah-senate-hatch-vs-howell       0.37       utah   0.3533
# 1         2012-utah-senate-hatch-vs-howell       0.39       utah   0.3533
# 2  2012-tennessee-senate-corker-vs-clayton       0.33  tennessee   0.3448
# 3  2012-tennessee-senate-corker-vs-clayton       0.38  tennessee   0.3448
# 4  2012-tennessee-senate-corker-vs-clayton       0.21  tennessee   0.3448

# %%
sns.lmplot('poll_diff', 'rd_diff', data=final_df)
plt.xlabel('Poll Predictions')
plt.ylabel('True Outcome (Popular Vote)')
plt.show()

# %%
from sklearn.linear_model import LinearRegression
clf_l, Xtrain_l, ytrain_l, Xtest_l, ytest_l  = do_classify(LinearRegression(), {"C": [0.01, 0.1, 1, 10, 100]}, final_df, ['Weight', 'Height'], 'Gender','Male')

# %% [markdown]
# #### Problem 4(b)
#
# Predict the R-D difference in each state. The predictions that minimize the residual sum of squares between predicted and observed differences wins.

# %%
### Your code here ###

# %% [markdown]
# **Provide an explanation of methodology here**:

# %% [markdown]
# #### Problem 4(c)
#
# Report a confidence interval for the R-D difference in each state. If the election day result falls outside your confidence interval in more than two states you are eliminated. For those surviving this cutoff, we will add up the size of all confidence intervals and sum. The smallest total length of confidence interval wins.
#
# **Note**: you can use Bayesian credible intervals or whatever else you want.

# %%
### Your code here ###

# %% [markdown]
# **Provide an explanation of methodology here**:

# %% [markdown]
# # Submission Instructions
#
# To submit your homework, create a folder named **lastname_firstinitial_hw#** and place your IPython notebooks, data files, and any other files in this folder. Your IPython Notebooks should be completely executed with the results visible in the notebook. We should not have to run any code.  Compress the folder (please use .zip compression) and submit to the CS109 dropbox in the appropriate folder. *If we cannot access your work because these directions are not followed correctly, we will not grade your work.*
